# %% [markdown]
# <a href="https://colab.research.google.com/github/GalHillel/Final-Project-PhotoGrammetry/blob/main/pgm_p3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 1. Initial Setup: Configuration, GPU Validation, Drive Inspection, and Cleanup

# %%
# Upgrade to yt-dlp for video downloading (replacing youtube-dl)
# !pip install -U yt-dlp



# Install OpenCV with a version that is compatible with GPU (CUDA support)
# !pip install opencv-python-headless==4.5.4.60

# Install PyTorch to confirm GPU availability
# !pip install torch torchvision torchaudio

# Install other dependencies
# !pip install pysrt  # For handling SRT file parsing
# Out:
# Requirement already satisfied: yt-dlp in /usr/local/lib/python3.10/dist-packages (2024.10.22)
# Requirement already satisfied: brotli in /usr/local/lib/python3.10/dist-packages (from yt-dlp) (1.1.0)
# Requirement already satisfied: certifi in /usr/local/lib/python3.10/dist-packages (from yt-dlp) (2024.8.30)
# Requirement already satisfied: mutagen in /usr/local/lib/python3.10/dist-packages (from yt-dlp) (1.47.0)
# Requirement already satisfied: pycryptodomex in /usr/local/lib/python3.10/dist-packages (from yt-dlp) (3.21.0)
# Requirement already satisfied: requests<3,>=2.32.2 in /usr/local/lib/python3.10/dist-packages (from yt-dlp) (2.32.3)
# Requirement already satisfied: urllib3<3,>=1.26.17 in /usr/local/lib/python3.10/dist-packages (from yt-dlp) (2.2.3)
# Requirement already satisfied: websockets>=13.0 in /usr/local/lib/python3.10/dist-packages (from yt-dlp) (13.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.32.2->yt-dlp) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.32.2->yt-dlp) (3.10)
# Requirement already satisfied: opencv-python-headless==4.5.4.60 in /usr/local/lib/python3.10/dist-packages (4.5.4.60)
# Requirement already satisfied: numpy>=1.21.2 in /usr/local/lib/python3.10/dist-packages (from opencv-python-headless==4.5.4.60) (1.26.4)
# Requirement already satisfied: torch in /usr/local/lib/python3.10/dist-packages (2.5.0+cu121)
# Requirement already satisfied: torchvision in /usr/local/lib/python3.10/dist-packages (0.20.0+cu121)
# Requirement already satisfied: torchaudio in /usr/local/lib/python3.10/dist-packages (2.5.0+cu121)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch) (3.16.1)
# Requirement already satisfied: typing-extensions>=4.8.0 in /usr/local/lib/python3.10/dist-packages (from torch) (4.12.2)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch) (3.4.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch) (3.1.4)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from torch) (2024.6.1)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.10/dist-packages (from torch) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from sympy==1.13.1->torch) (1.3.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from torchvision) (1.26.4)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /usr/local/lib/python3.10/dist-packages (from torchvision) (10.4.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch) (3.0.2)
# Requirement already satisfied: pysrt in /usr/local/lib/python3.10/dist-packages (1.1.2)
# Requirement already satisfied: chardet in /usr/local/lib/python3.10/dist-packages (from pysrt) (5.2.0)

# %%
import shutil
import pysrt

from datetime import datetime

def backup_data():
    # Create a unique backup directory using milliseconds to avoid name collisions
    timestamp = datetime.now().strftime("%Y%m%d_%H%M%S%f")
    backup_dir = os.path.join(BACKUP_DIR, timestamp)
    os.makedirs(backup_dir, exist_ok=True)

    try:
        # Paths for specific backup folders
        state_backup = os.path.join(backup_dir, "progress_state.json")
        model_backup_dir = os.path.join(backup_dir, "models")
        frame_backup_dir = os.path.join(backup_dir, "frames")

        os.makedirs(model_backup_dir, exist_ok=True)
        os.makedirs(frame_backup_dir, exist_ok=True)

        # Copy the progress state file if it exists
        if os.path.exists(STATE_FILE_PATH):
            shutil.copy(STATE_FILE_PATH, state_backup)

        # Copy model directories with overwrite handling
        for model_folder in os.listdir(MODEL_DIR):
            model_src = os.path.join(MODEL_DIR, model_folder)
            model_dest = os.path.join(model_backup_dir, model_folder)
            if os.path.exists(model_dest):
                shutil.rmtree(model_dest)  # Remove the existing directory if necessary
            shutil.copytree(model_src, model_dest)
            logger.info(f"Backed up model directory: {model_dest}")

        # Copy frame directories with overwrite handling
        for frame_folder in os.listdir(FRAME_DIR):
            frame_src = os.path.join(FRAME_DIR, frame_folder)
            frame_dest = os.path.join(frame_backup_dir, frame_folder)
            if os.path.exists(frame_dest):
                shutil.rmtree(frame_dest)  # Remove the existing directory if necessary
            shutil.copytree(frame_src, frame_dest)
            logger.info(f"Backed up frame directory: {frame_dest}")

        logger.info("Backup completed successfully to Google Drive with timestamped directory.")

    except Exception as e:
        logger.error(f"Backup failed: {e}")

# %%
import torch
import cv2
import subprocess

def validate_gpu():
    # Check GPU availability with PyTorch
    if torch.cuda.is_available():
        print(f"PyTorch GPU available: {torch.cuda.get_device_name(0)}")
        print("Number of GPUs available:", torch.cuda.device_count())
    else:
        print("No GPU detected by PyTorch.")

    # Check GPU availability for OpenCV with CUDA (requires OpenCV with CUDA build)
    try:
        gpu_count = cv2.cuda.getCudaEnabledDeviceCount()
        if gpu_count > 0:
            print(f"OpenCV GPU available: {gpu_count} CUDA-enabled device(s) detected.")
        else:
            print("No GPU detected by OpenCV with CUDA support.")
    except AttributeError:
        print("OpenCV CUDA support not found. Make sure OpenCV is installed with CUDA.")

    # Verify CUDA installation for other GPU-dependent libraries
    cuda_check = subprocess.run(['nvcc', '--version'], stdout=subprocess.PIPE, text=True)
    if cuda_check.returncode == 0:
        print("CUDA installation found:", cuda_check.stdout)
    else:
        print("CUDA not found. Please install CUDA if required for your environment.")

# %%
import os
import json
import logging
from datetime import datetime, timedelta
import time
import subprocess
import cv2
import numpy as np
import shutil

# Define constants and paths
ROOT_DIR = "/content/drive/MyDrive/PhotoGrammetry"
VIDEO_DIR = os.path.join(ROOT_DIR, "videos")
FRAME_DIR = os.path.join(ROOT_DIR, "frames")
MODEL_DIR = os.path.join(ROOT_DIR, "models")
LOG_DIR = os.path.join(ROOT_DIR, "logs")
BACKUP_DIR = os.path.join(ROOT_DIR, "backups")
CONFIG_PATH = os.path.join(ROOT_DIR, "config.json")
STATE_FILE_PATH = os.path.join(ROOT_DIR, "progress_state.json")

# Configure logging
logging.basicConfig(level=logging.INFO, format='%(asctime)s - %(levelname)s - %(message)s')
logger = logging.getLogger(__name__)

# Load configuration
def load_config():
    if not os.path.exists(CONFIG_PATH):
        raise FileNotFoundError("Config file not found in Google Drive.")
    with open(CONFIG_PATH, 'r') as f:
        return json.load(f)
config = load_config()

# Check GPU availability
def validate_gpu():
    gpu_count = cv2.cuda.getCudaEnabledDeviceCount()
    if gpu_count > 0:
        logger.info(f"GPU available: {gpu_count} CUDA-enabled device(s) detected.")
    else:
        logger.warning("No GPU detected. Processing will proceed on CPU.")


# Check and inspect files in Google Drive
def inspect_drive():
    logger.info("Inspecting Google Drive structure...")
    for directory in [VIDEO_DIR, FRAME_DIR, MODEL_DIR, LOG_DIR, BACKUP_DIR]:
        if not os.path.exists(directory):
            os.makedirs(directory)
            logger.info(f"Created missing directory: {directory}")
        else:
            files = os.listdir(directory)
            logger.info(f"{directory} contains {len(files)} files.")

# %%
# Mount Google Drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import torch
print("GPU available:", torch.cuda.is_available())
print("GPU count:", torch.cuda.device_count())
inspect_drive()
validate_gpu()
# Out:
# WARNING:__main__:No GPU detected. Processing will proceed on CPU.
# GPU available: True
# GPU count: 1

# %%
# Path to Meshroom tar file and extraction directory
MESHROOM_TAR_PATH = "/content/drive/MyDrive/Meshroom-2023.3.0-linux.tar.gz"
MESHROOM_DIR = "/content/Meshroom-2023.3.0"

# Extract Meshroom
import tarfile
import os

if not os.path.exists(MESHROOM_DIR):
    with tarfile.open(MESHROOM_TAR_PATH, "r:gz") as tar:
        tar.extractall(path="/content/")
    print("Meshroom extracted successfully.")
else:
    print("Meshroom directory already exists.")

# Add Meshroom to system path for easy access to `meshroom_batch`
os.environ["PATH"] += os.pathsep + os.path.join(MESHROOM_DIR)

# Verify Meshroom setup
# !meshroom_batch --help
# Out:
# Meshroom directory already exists.
# usage: meshroom_batch [-h]
#                       [-i [NODEINSTANCE:"SFM/FOLDERS/IMAGES;..." [NODEINSTANCE:"SFM/FOLDERS/IMAGES;..." ...]]]
#                       [-I [NODEINSTANCE:"FOLDERS/IMAGES;..." [NODEINSTANCE:"FOLDERS/IMAGES;..." ...]]]
#                       [-p FILE.mg/photogrammetryAndCameraTracking/cameraTrackingWithoutCalibration/cameraTracking/panoramaHdr/hdrFusion/distortionCalibration/nodalCameraTracking/stereoPhotometry/photogrammetry/panoramaFisheyeHdr/photogrammetryDraft]
#                       [--overrides SETTINGS]
#                       [--paramOverrides [NODETYPE:param=value NODEINSTANCE.param=value [NODETYPE:param=value NODEINSTANCE.param=value ...]]]
#                       [-o FOLDER] [--cache FOLDER] [--save FILE] [--compute <yes/no>]
#                       [--toNode [NODE [NODE ...]]] [--forceStatus] [--forceCompute] [--submit]
#                       [--submitLabel SUBMITLABEL] [--submitter SUBMITTER]
#                       [-v {,fatal,error,warning,info,debug,trace}]
#
# Launch the full photogrammetry or Panorama HDR pipeline.
#
# optional arguments:
#   -h, --help            show this help message and exit
#   -i [NODEINSTANCE:"SFM/FOLDERS/IMAGES;..." [NODEINSTANCE:"SFM/FOLDERS/IMAGES;..." ...]], --input [NODEINSTANCE:"SFM/FOLDERS/IMAGES;..." [NODEINSTANCE:"SFM/FOLDERS/IMAGES;..." ...]]
#                         Input folder containing images or folders of images or file (.sfm or
#                         .json) with images paths and optionally predefined camera intrinsics.
#   -I [NODEINSTANCE:"FOLDERS/IMAGES;..." [NODEINSTANCE:"FOLDERS/IMAGES;..." ...]], --inputRecursive [NODEINSTANCE:"FOLDERS/IMAGES;..." [NODEINSTANCE:"FOLDERS/IMAGES;..." ...]]
#                         Input folders containing all images recursively.
#   -p FILE.mg/photogrammetryAndCameraTracking/cameraTrackingWithoutCalibration/cameraTracking/panoramaHdr/hdrFusion/distortionCalibration/nodalCameraTracking/stereoPhotometry/photogrammetry/panoramaFisheyeHdr/photogrammetryDraft, --pipeline FILE.mg/photogrammetryAndCameraTracking/cameraTrackingWithoutCalibration/cameraTracking/panoramaHdr/hdrFusion/distortionCalibration/nodalCameraTracking/stereoPhotometry/photogrammetry/panoramaFisheyeHdr/photogrammetryDraft
#                         Template pipeline among those listed or a Meshroom file containing a
#                         custom pipeline to run on input images. Requirements: the graph must
#                         contain one CameraInit node, and one Publish node if --output is set.
#   --overrides SETTINGS  A JSON file containing the graph parameters override.
#   --paramOverrides [NODETYPE:param=value NODEINSTANCE.param=value [NODETYPE:param=value NODEINSTANCE.param=value ...]]
#                         Override specific parameters directly from the command line (by node type
#                         or by node names).
#   -o FOLDER, --output FOLDER
#                         Output folder where results should be copied to. If not set, results will
#                         have to be retrieved directly from the cache folder.
#   --cache FOLDER        Custom cache folder to write computation results. If not set, the default
#                         cache folder will be used: /tmp/MeshroomCache
#   --save FILE           Save the configured Meshroom graph to a project file. It will setup the
#                         cache folder accordingly if not explicitly changed by --cache.
#   --compute <yes/no>    You can set it to <no/false/0> to disable the computation.
#   --toNode [NODE [NODE ...]]
#                         Process the node(s) with its dependencies.
#   --forceStatus         Force computation if status is RUNNING or SUBMITTED.
#   --forceCompute        Compute in all cases even if already computed.
#   --submit              Submit on renderfarm instead of local computation.
#   --submitLabel SUBMITLABEL
#                         Label of a node in the submitter
#   --submitter SUBMITTER
#                         Execute job with a specific submitter.
#   -v {,fatal,error,warning,info,debug,trace}, --verbose {,fatal,error,warning,info,debug,trace}
#                         Verbosity level

# %% [markdown]
# # 2. Cleanup of Incomplete or Temporary Files

# %%
def cleanup_incomplete_runs():
    # Identify incomplete or temporary files and delete them
    logger.info("Performing cleanup of incomplete runs...")
    for model_folder in os.listdir(MODEL_DIR):
        model_path = os.path.join(MODEL_DIR, model_folder)
        if "incomplete" in model_folder:
            shutil.rmtree(model_path, ignore_errors=True)
            logger.info(f"Removed incomplete model data: {model_path}")
    for frame_folder in os.listdir(FRAME_DIR):
        frame_path = os.path.join(FRAME_DIR, frame_folder)
        if not os.listdir(frame_path):
            shutil.rmtree(frame_path, ignore_errors=True)
            logger.info(f"Removed empty frame directory: {frame_path}")
cleanup_incomplete_runs()

# %% [markdown]
# # 3. State Management for Recovery

# %%
def load_state():
    if os.path.exists(STATE_FILE_PATH):
        with open(STATE_FILE_PATH, 'r') as f:
            return json.load(f)
    return {}

def save_state(state):
    with open(STATE_FILE_PATH, 'w') as f:
        json.dump(state, f, indent=4)

# Initialize state
state = load_state()

# %% [markdown]
# # 4. Logging and Progress Tracking

# %%
def log_with_progress(message, current, total):
    percent_complete = (current / total) * 100
    logger.info(f"{message} - {percent_complete:.2f}% complete ({current}/{total})")

# %% [markdown]
# # 5. File Naming Helpers

# %%
def get_file_name(prefix, mission_id, ext, sequence=None):
    mission_str = f"{mission_id:04d}"
    if sequence is not None:
        return f"{prefix}_{mission_str}_{sequence:04d}.{ext}"
    return f"{prefix}_{mission_str}.{ext}"

# %% [markdown]
# # 6. Video Download and Conversion

# %%
# !pip install -U yt-dlp
# Out:
# Requirement already satisfied: yt-dlp in /usr/local/lib/python3.10/dist-packages (2024.10.22)
# Requirement already satisfied: brotli in /usr/local/lib/python3.10/dist-packages (from yt-dlp) (1.1.0)
# Requirement already satisfied: certifi in /usr/local/lib/python3.10/dist-packages (from yt-dlp) (2024.8.30)
# Requirement already satisfied: mutagen in /usr/local/lib/python3.10/dist-packages (from yt-dlp) (1.47.0)
# Requirement already satisfied: pycryptodomex in /usr/local/lib/python3.10/dist-packages (from yt-dlp) (3.21.0)
# Requirement already satisfied: requests<3,>=2.32.2 in /usr/local/lib/python3.10/dist-packages (from yt-dlp) (2.32.3)
# Requirement already satisfied: urllib3<3,>=1.26.17 in /usr/local/lib/python3.10/dist-packages (from yt-dlp) (2.2.3)
# Requirement already satisfied: websockets>=13.0 in /usr/local/lib/python3.10/dist-packages (from yt-dlp) (13.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.32.2->yt-dlp) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.32.2->yt-dlp) (3.10)

# %%
import yt_dlp

def download_video(youtube_id, mission_id):
    try:
        video_path = os.path.join(VIDEO_DIR, get_file_name("video", mission_id, "mp4"))
        if os.path.exists(video_path):
            logger.info(f"Video already exists for mission {mission_id}. Skipping download.")
            return video_path
        ydl_opts = {
            'format': 'bestvideo[ext=mp4]+bestaudio[ext=m4a]/best[ext=mp4]',
            'outtmpl': video_path
        }
        with yt_dlp.YoutubeDL(ydl_opts) as ydl:
            ydl.download([f"https://www.youtube.com/watch?v={youtube_id}"])
        logger.info(f"Downloaded video for mission {mission_id}")
        return video_path
    except Exception as e:
        logger.error(f"Error downloading video {youtube_id} for mission {mission_id}: {e}")
        return None

# %% [markdown]
# # 7. SRT Parsing for GPS Data

# %%
import re
import pysrt
def parse_dji_srt(srt_path, mission_id):
    gps_data = []
    log_entries = pysrt.open(srt_path)
    gps_pattern = re.compile(r'GPS \(([-\d.]+), ([-\d.]+)\) Altitude ([-\d.]+) m')

    for entry in log_entries:
        print(f"Parsing line: {entry.text}")  # Debugging line to inspect each entry
        match = gps_pattern.search(entry.text)
        if match:
            latitude = float(match.group(1))
            longitude = float(match.group(2))
            altitude = float(match.group(3))
            gps_data.append({
                "timestamp": entry.start.to_time().isoformat(),
                "latitude": latitude,
                "longitude": longitude,
                "altitude": altitude
            })
    if not gps_data:
        print(f"No GPS data found in {srt_path}. Check format or regex pattern.")
    return gps_data

# %% [markdown]
# # 8. Frame Extraction with Dynamic Sampling

# %%
def haversine(lat1, lon1, lat2, lon2):
    R = 6371e3  # Earth radius in meters
    phi1, phi2 = np.radians(lat1), np.radians(lat2)
    delta_phi = np.radians(lat2 - lat1)
    delta_lambda = np.radians(lon2 - lon1)
    a = np.sin(delta_phi / 2) ** 2 + np.cos(phi1) * np.cos(phi2) * np.sin(delta_lambda / 2) ** 2
    c = 2 * np.arctan2(np.sqrt(a), np.sqrt(1 - a))
    return R * c

def capture_frames(video_path, mission_id, gps_data=None, base_sampling_rate=10, max_frames=1000):
    output_folder = os.path.join(FRAME_DIR, f"{mission_id:04d}")
    os.makedirs(output_folder, exist_ok=True)
    cap = cv2.VideoCapture(video_path)
    total_frames = int(cap.get(cv2.CAP_PROP_FRAME_COUNT))
    frame_rate = cap.get(cv2.CAP_PROP_FPS)
    saved_frames = 0
    previous_coords = None
    dynamic_sampling_rate = base_sampling_rate
    start_time = time.time()

    for i, gps_point in enumerate(gps_data):
        if saved_frames >= max_frames:
            break
        elapsed_time = time.time() - start_time
        eta = timedelta(seconds=int(elapsed_time / (saved_frames + 1) * (max_frames - saved_frames)))
        if previous_coords:
            lat1, lon1 = previous_coords
            lat2, lon2 = gps_point["latitude"], gps_point["longitude"]
            distance_moved = haversine(lat1, lon1, lat2, lon2)
            dynamic_sampling_rate = max(1, base_sampling_rate // 2 if distance_moved > 5 else base_sampling_rate * 2)
        previous_coords = (gps_point["latitude"], gps_point["longitude"])
        frame_number = int(i * dynamic_sampling_rate * frame_rate)
        if frame_number >= total_frames:
            break
        cap.set(cv2.CAP_PROP_POS_FRAMES, frame_number)
        ret, frame = cap.read()
        if not ret:
            continue
        frame_name = get_file_name("frame", mission_id, "jpg", saved_frames)
        cv2.imwrite(os.path.join(output_folder, frame_name), frame)
        saved_frames += 1
        log_with_progress(f"Frame extraction for mission {mission_id}", saved_frames, max_frames)
        logger.info(f"ETA for mission {mission_id} - {eta}")

    cap.release()
    logger.info(f"Total frames saved for mission {mission_id}: {saved_frames}")

# %% [markdown]
# # 9. Meshroom Processing with GPU

# %%
def run_meshroom(mission_id):
    frames_folder = os.path.join(FRAME_DIR, f"{mission_id:04d}")
    model_folder = os.path.join(MODEL_DIR, f"model_{mission_id:04d}")
    os.makedirs(model_folder, exist_ok=True)

    meshroom_log = os.path.join(model_folder, "meshroom_log.txt")

    try:
        start_time = time.time()
        result = subprocess.run(
            ["meshroom_batch", "--input", frames_folder, "--output", model_folder],
            stdout=subprocess.PIPE, stderr=subprocess.STDOUT, text=True
        )
        elapsed_time = time.time() - start_time
        with open(meshroom_log, "w") as log_file:
            log_file.write(result.stdout)

        logger.info(f"Meshroom processing completed for mission {mission_id} in {timedelta(seconds=int(elapsed_time))}")
    except subprocess.CalledProcessError as e:
        logger.error(f"Meshroom encountered an error for mission {mission_id}: {e}")

# %% [markdown]
# # 10. Backup and Persistence

# %%
def backup_data():
    timestamp = datetime.now().strftime("%Y%m%d_%H%M%S%f")  # Milliseconds for uniqueness
    backup_dir = os.path.join(BACKUP_DIR, timestamp)
    os.makedirs(backup_dir, exist_ok=True)

    try:
        model_backup_dir = os.path.join(backup_dir, "models")
        os.makedirs(model_backup_dir, exist_ok=True)

        for model_folder in os.listdir(MODEL_DIR):
            model_src = os.path.join(MODEL_DIR, model_folder)
            model_dest = os.path.join(model_backup_dir, model_folder)
            if os.path.exists(model_dest):
                shutil.rmtree(model_dest)  # Remove before overwriting
            shutil.copytree(model_src, model_dest)
            logger.info(f"Backed up model directory: {model_dest}")

        logger.info("Backup completed successfully.")

    except Exception as e:
        logger.error(f"Backup failed: {e}")

# %% [markdown]
# # 11. Main Orchestrator Function

# %%
def setup_directories():
    for dir_path in [VIDEO_DIR, FRAME_DIR, MODEL_DIR, LOG_DIR, BACKUP_DIR]:
        os.makedirs(dir_path, exist_ok=True)
    logger.info("Directories set up successfully.")

# %%
def orchestrate_process(config):
    setup_directories()

    for mission in config["missions"]:
        mission_id = mission["id"]
        state.setdefault(str(mission_id), {"downloaded": False, "frames_extracted": False, "meshroom_processed": False})

        video_path = None  # Initialize video_path to None at the start of each loop

        # Step 1: Download video
        if not state[str(mission_id)]["downloaded"]:
            video_path = download_video(mission["youtube_id"], mission_id)
            if video_path:
                state[str(mission_id)]["downloaded"] = True
                save_state(state)

        # Step 2: Parse GPS data if log file exists
        gps_data = None
        if mission.get("flight_log") and not state[str(mission_id)].get("gps_parsed"):
            log_file_path = os.path.join(LOG_DIR, mission["flight_log"])
            gps_data = parse_dji_srt(log_file_path, mission_id)
            if gps_data:  # Ensure GPS data is available
                state[str(mission_id)]["gps_parsed"] = True
                save_state(state)
            else:
                logger.warning(f"No GPS data parsed for mission {mission_id}. Skipping frame capture.")

        # Step 3: Extract frames only if video and GPS data are available
        if video_path and gps_data and not state[str(mission_id)]["frames_extracted"]:
            capture_frames(video_path, mission_id, gps_data)
            state[str(mission_id)]["frames_extracted"] = True
            save_state(state)

        # Step 4: Run Meshroom processing
        if not state[str(mission_id)]["meshroom_processed"]:
            run_meshroom(mission_id)
            state[str(mission_id)]["meshroom_processed"] = True
            save_state(state)

        # Backup and save progress at each stage
        backup_data()

# %%
import json
with open(CONFIG_PATH, 'r') as f:
    config = json.load(f)

orchestrate_process(config)
# Out:
# Streaming output truncated to the last 5000 lines.
# 2024-06-19 11:13:53.999
# [iso : 150] [shutter : 1/6000.0] [fnum : 170] [ev : 0] [ct : 4968] [color_md : default] [focal_len : 240] [dzoom_ratio: 10000, delta:0],[latitude: 32.105570] [longitude: 35.206576] [rel_alt: 117.600 abs_alt: 802.641] </font>
# Parsing line: <font size="28">SrtCnt : 22266, DiffTime : 33ms
# 2024-06-19 11:13:54.032
# [iso : 150] [shutter : 1/6000.0] [fnum : 170] [ev : 0] [ct : 4967] [color_md : default] [focal_len : 240] [dzoom_ratio: 10000, delta:0],[latitude: 32.105578] [longitude: 35.206580] [rel_alt: 117.600 abs_alt: 802.641] </font>
# Parsing line: <font size="28">SrtCnt : 22267, DiffTime : 34ms
# 2024-06-19 11:13:54.065
# [iso : 150] [shutter : 1/6000.0] [fnum : 170] [ev : 0] [ct : 4967] [color_md : default] [focal_len : 240] [dzoom_ratio: 10000, delta:0],[latitude: 32.105578] [longitude: 35.206580] [rel_alt: 117.600 abs_alt: 802.641] </font>
# Parsing line: <font size="28">SrtCnt : 22268, DiffTime : 33ms
# 2024-06-19 11:13:54.099
# [iso : 150] [shutter : 1/6000.0] [fnum : 170] [ev : 0] [ct : 4966] [color_md : default] [focal_len : 240] [dzoom_ratio: 10000, delta:0],[latitude: 32.105578] [longitude: 35.206580] [rel_alt: 117.600 abs_alt: 802.641] </font>
# Parsing line: <font size="28">SrtCnt : 22269, DiffTime : 33ms
# 2024-06-19 11:13:54.132
# [iso : 150] [shutter : 1/6000.0] [fnum : 170] [ev : 0] [ct : 4966] [color_md : default] [focal_len : 240] [dzoom_ratio: 10000, delta:0],[latitude: 32.105586] [longitude: 35.206584] [rel_alt: 117.600 abs_alt: 802.641] </font>
# Parsing line: <font size="28">SrtCnt : 22270, DiffTime : 34ms
# 2024-06-19 11:13:54.165
# [iso : 150] [shutter : 1/6000.0] [fnum : 170] [ev : 0] [ct : 4966] [color_md : default] [focal_len : 240] [dzoom_ratio: 10000, delta:0],[latitude: 32.105586] [longitude: 35.206584] [rel_alt: 117.600 abs_alt: 802.641] </font>
# Parsing line: <font size="28">SrtCnt : 22271, DiffTime : 33ms
# 2024-06-19 11:13:54.199
# [iso : 150] [shutter : 1/6000.0] [fnum : 170] [ev : 0] [ct : 4966] [color_md : default] [focal_len : 240] [dzoom_ratio: 10000, delta:0],[latitude: 32.105586] [longitude: 35.206584] [rel_alt: 117.600 abs_alt: 802.641] </font>
# Parsing line: <font size="28">SrtCnt : 22272, DiffTime : 33ms
# 2024-06-19 11:13:54.232
# [iso : 150] [shutter : 1/6000.0] [fnum : 170] [ev : 0] [ct : 4966] [color_md : default] [focal_len : 240] [dzoom_ratio: 10000, delta:0],[latitude: 32.105595] [longitude: 35.206589] [rel_alt: 117.600 abs_alt: 802.641] </font>
# Parsing line: <font size="28">SrtCnt : 22273, DiffTime : 34ms
# 2024-06-19 11:13:54.266
# [iso : 150] [shutter : 1/6000.0] [fnum : 170] [ev : 0] [ct : 4966] [color_md : default] [focal_len : 240] [dzoom_ratio: 10000, delta:0],[latitude: 32.105595] [longitude: 35.206589] [rel_alt: 117.600 abs_alt: 802.641] </font>
# Parsing line: <font size="28">SrtCnt : 22274, DiffTime : 33ms
# 2024-06-19 11:13:54.299
# [iso : 150] [shutter : 1/6000.0] [fnum : 170] [ev : 0] [ct : 4966] [color_md : default] [focal_len : 240] [dzoom_ratio: 10000, delta:0],[latitude: 32.105595] [longitude: 35.206589] [rel_alt: 117.600 abs_alt: 802.641] </font>
# Parsing line: <font size="28">SrtCnt : 22275, DiffTime : 34ms
# 2024-06-19 11:13:54.332
# [iso : 150] [shutter : 1/6000.0] [fnum : 170] [ev : 0] [ct : 4966] [color_md : default] [focal_len : 240] [dzoom_ratio: 10000, delta:0],[latitude: 32.105603] [longitude: 35.206593] [rel_alt: 117.600 abs_alt: 802.641] </font>
# Parsing line: <font size="28">SrtCnt : 22276, DiffTime : 33ms
# 2024-06-19 11:13:54.366
# [iso : 150] [shutter : 1/6000.0] [fnum : 170] [ev : 0] [ct : 4965] [color_md : default] [focal_len : 240] [dzoom_ratio: 10000, delta:0],[latitude: 32.105603] [longitude: 35.206593] [rel_alt: 117.600 abs_alt: 802.641] </font>
# Parsing line: <font size="28">SrtCnt : 22277, DiffTime : 33ms
# 2024-06-19 11:13:54.399
# [iso : 150] [shutter : 1/6000.0] [fnum : 170] [ev : 0] [ct : 4965] [color_md : default] [focal_len : 240] [dzoom_ratio: 10000, delta:0],[latitude: 32.105603] [longitude: 35.206593] [rel_alt: 117.600 abs_alt: 802.641] </font>
# Parsing line: <font size="28">SrtCnt : 22278, DiffTime : 34ms
# 2024-06-19 11:13:54.432
# [iso : 150] [shutter : 1/6000.0] [fnum : 170] [ev : 0] [ct : 4964] [color_md : default] [focal_len : 240] [dzoom_ratio: 10000, delta:0],[latitude: 32.105611] [longitude: 35.206597] [rel_alt: 117.600 abs_alt: 802.641] </font>
# Parsing line: <font size="28">SrtCnt : 22279, DiffTime : 33ms
# 2024-06-19 11:13:54.466
# [iso : 150] [shutter : 1/6000.0] [fnum : 170] [ev : 0] [ct : 4964] [color_md : default] [focal_len : 240] [dzoom_ratio: 10000, delta:0],[latitude: 32.105611] [longitude: 35.206597] [rel_alt: 117.600 abs_alt: 802.641] </font>
# Parsing line: <font size="28">SrtCnt : 22280, DiffTime : 33ms
# 2024-06-19 11:13:54.499
# [iso : 150] [shutter : 1/6000.0] [fnum : 170] [ev : 0] [ct : 4964] [color_md : default] [focal_len : 240] [dzoom_ratio: 10000, delta:0],[latitude: 32.105611] [longitude: 35.206597] [rel_alt: 117.600 abs_alt: 802.641] </font>
# Parsing line: <font size="28">SrtCnt : 22281, DiffTime : 34ms
# 2024-06-19 11:13:54.532
# [iso : 150] [shutter : 1/6000.0] [fnum : 170] [ev : 0] [ct : 4964] [color_md : default] [focal_len : 240] [dzoom_ratio: 10000, delta:0],[latitude: 32.105619] [longitude: 35.206601] [rel_alt: 117.600 abs_alt: 802.641] </font>
# Parsing line: <font size="28">SrtCnt : 22282, DiffTime : 33ms
# 2024-06-19 11:13:54.566
# [iso : 150] [shutter : 1/6000.0] [fnum : 170] [ev : 0] [ct : 4962] [color_md : default] [focal_len : 240] [dzoom_ratio: 10000, delta:0],[latitude: 32.105619] [longitude: 35.206601] [rel_alt: 117.600 abs_alt: 802.641] </font>
# Parsing line: <font size="28">SrtCnt : 22283, DiffTime : 33ms
# 2024-06-19 11:13:54.599
# [iso : 150] [shutter : 1/6000.0] [fnum : 170] [ev : 0] [ct : 4962] [color_md : default] [focal_len : 240] [dzoom_ratio: 10000, delta:0],[latitude: 32.105619] [longitude: 35.206601] [rel_alt: 117.600 abs_alt: 802.641] </font>
# Parsing line: <font size="28">SrtCnt : 22284, DiffTime : 34ms
# 2024-06-19 11:13:54.632
# [iso : 150] [shutter : 1/6000.0] [fnum : 170] [ev : 0] [ct : 4961] [color_md : default] [focal_len : 240] [dzoom_ratio: 10000, delta:0],[latitude: 32.105628] [longitude: 35.206606] [rel_alt: 117.600 abs_alt: 802.641] </font>
# Parsing line: <font size="28">SrtCnt : 22285, DiffTime : 33ms
# 2024-06-19 11:13:54.666
# [iso : 150] [shutter : 1/6000.0] [fnum : 170] [ev : 0] [ct : 4961] [color_md : default] [focal_len : 240] [dzoom_ratio: 10000, delta:0],[latitude: 32.105628] [longitude: 35.206606] [rel_alt: 117.600 abs_alt: 802.641] </font>
# Parsing line: <font size="28">SrtCnt : 22286, DiffTime : 34ms
# 2024-06-19 11:13:54.701
# [iso : 150] [shutter : 1/6000.0] [fnum : 170] [ev : 0] [ct : 4959] [color_md : default] [focal_len : 240] [dzoom_ratio: 10000, delta:0],[latitude: 32.105628] [longitude: 35.206606] [rel_alt: 117.600 abs_alt: 802.641] </font>
# Parsing line: <font size="28">SrtCnt : 22287, DiffTime : 33ms
# 2024-06-19 11:13:54.732
# [iso : 150] [shutter : 1/6000.0] [fnum : 170] [ev : 0] [ct : 4959] [color_md : default] [focal_len : 240] [dzoom_ratio: 10000, delta:0],[latitude: 32.105636] [longitude: 35.206610] [rel_alt: 117.600 abs_alt: 802.641] </font>
# Parsing line: <font size="28">SrtCnt : 22288, DiffTime : 33ms
# 2024-06-19 11:13:54.766
# [iso : 150] [shutter : 1/6000.0] [fnum : 170] [ev : 0] [ct : 4957] [color_md : default] [focal_len : 240] [dzoom_ratio: 10000, delta:0],[latitude: 32.105636] [longitude: 35.206610] [rel_alt: 117.600 abs_alt: 802.641] </font>
# Parsing line: <font size="28">SrtCnt : 22289, DiffTime : 34ms
# 2024-06-19 11:13:54.801
# [iso : 150] [shutter : 1/6000.0] [fnum : 170] [ev : 0] [ct : 4957] [color_md : default] [focal_len : 240] [dzoom_ratio: 10000, delta:0],[latitude: 32.105636] [longitude: 35.206610] [rel_alt: 117.600 abs_alt: 802.641] </font>
# Parsing line: <font size="28">SrtCnt : 22290, DiffTime : 33ms
# 2024-06-19 11:13:54.832
# [iso : 150] [shutter : 1/6000.0] [fnum : 170] [ev : 0] [ct : 4955] [color_md : default] [focal_len : 240] [dzoom_ratio: 10000, delta:0],[latitude: 32.105644] [longitude: 35.206614] [rel_alt: 117.600 abs_alt: 802.641] </font>
# Parsing line: <font size="28">SrtCnt : 22291, DiffTime : 33ms
# 2024-06-19 11:13:54.866
# [iso : 150] [shutter : 1/6000.0] [fnum : 170] [ev : 0] [ct : 4955] [color_md : default] [focal_len : 240] [dzoom_ratio: 10000, delta:0],[latitude: 32.105644] [longitude: 35.206614] [rel_alt: 117.600 abs_alt: 802.641] </font>
# Parsing line: <font size="28">SrtCnt : 22292, DiffTime : 34ms
# 2024-06-19 11:13:54.900
# [iso : 150] [shutter : 1/6000.0] [fnum : 170] [ev : 0] [ct : 4953] [color_md : default] [focal_len : 240] [dzoom_ratio: 10000, delta:0],[latitude: 32.105644] [longitude: 35.206614] [rel_alt: 117.600 abs_alt: 802.641] </font>
# Parsing line: <font size="28">SrtCnt : 22293, DiffTime : 33ms
# 2024-06-19 11:13:54.932
# [iso : 150] [shutter : 1/6000.0] [fnum : 170] [ev : 0] [ct : 4953] [color_md : default] [focal_len : 240] [dzoom_ratio: 10000, delta:0],[latitude: 32.105652] [longitude: 35.206618] [rel_alt: 117.600 abs_alt: 802.641] </font>
# Parsing line: <font size="28">SrtCnt : 22294, DiffTime : 33ms
# 2024-06-19 11:13:54.966
# [iso : 150] [shutter : 1/6000.0] [fnum : 170] [ev : 0] [ct : 4951] [color_md : default] [focal_len : 240] [dzoom_ratio: 10000, delta:0],[latitude: 32.105652] [longitude: 35.206618] [rel_alt: 117.600 abs_alt: 802.641] </font>
# Parsing line: <font size="28">SrtCnt : 22295, DiffTime : 34ms
# 2024-06-19 11:13:55.000
# [iso : 150] [shutter : 1/6000.0] [fnum : 170] [ev : 0] [ct : 4951] [color_md : default] [focal_len : 240] [dzoom_ratio: 10000, delta:0],[latitude: 32.105652] [longitude: 35.206618] [rel_alt: 117.600 abs_alt: 802.641] </font>
# Parsing line: <font size="28">SrtCnt : 22296, DiffTime : 33ms
# 2024-06-19 11:13:55.033
# [iso : 150] [shutter : 1/6000.0] [fnum : 170] [ev : 0] [ct : 4949] [color_md : default] [focal_len : 240] [dzoom_ratio: 10000, delta:0],[latitude: 32.105660] [longitude: 35.206623] [rel_alt: 117.500 abs_alt: 802.541] </font>
# Parsing line: <font size="28">SrtCnt : 22297, DiffTime : 34ms
# 2024-06-19 11:13:55.066
# [iso : 150] [shutter : 1/6000.0] [fnum : 170] [ev : 0] [ct : 4949] [color_md : default] [focal_len : 240] [dzoom_ratio: 10000, delta:0],[latitude: 32.105660] [longitude: 35.206623] [rel_alt: 117.500 abs_alt: 802.541] </font>
# Parsing line: <font size="28">SrtCnt : 22298, DiffTime : 33ms
# 2024-06-19 11:13:55.100
# [iso : 150] [shutter : 1/6000.0] [fnum : 170] [ev : 0] [ct : 4946] [color_md : default] [focal_len : 240] [dzoom_ratio: 10000, delta:0],[latitude: 32.105660] [longitude: 35.206623] [rel_alt: 117.500 abs_alt: 802.541] </font>
# Parsing line: <font size="28">SrtCnt : 22299, DiffTime : 33ms
# 2024-06-19 11:13:55.133
# [iso : 150] [shutter : 1/6000.0] [fnum : 170] [ev : 0] [ct : 4946] [color_md : default] [focal_len : 240] [dzoom_ratio: 10000, delta:0],[latitude: 32.105668] [longitude: 35.206627] [rel_alt: 117.500 abs_alt: 802.541] </font>
# Parsing line: <font size="28">SrtCnt : 22300, DiffTime : 34ms
# 2024-06-19 11:13:55.167
# [iso : 150] [shutter : 1/6000.0] [fnum : 170] [ev : 0] [ct : 4943] [color_md : default] [focal_len : 240] [dzoom_ratio: 10000, delta:0],[latitude: 32.105668] [longitude: 35.206627] [rel_alt: 117.500 abs_alt: 802.541] </font>
# Parsing line: <font size="28">SrtCnt : 22301, DiffTime : 33ms
# 2024-06-19 11:13:55.200
# [iso : 150] [shutter : 1/6000.0] [fnum : 170] [ev : 0] [ct : 4943] [color_md : default] [focal_len : 240] [dzoom_ratio: 10000, delta:0],[latitude: 32.105668] [longitude: 35.206627] [rel_alt: 117.500 abs_alt: 802.541] </font>
# Parsing line: <font size="28">SrtCnt : 22302, DiffTime : 33ms
# 2024-06-19 11:13:55.233
# [iso : 150] [shutter : 1/6000.0] [fnum : 170] [ev : 0] [ct : 4941] [color_md : default] [focal_len : 240] [dzoom_ratio: 10000, delta:0],[latitude: 32.105677] [longitude: 35.206631] [rel_alt: 117.500 abs_alt: 802.541] </font>
# Parsing line: <font size="28">SrtCnt : 22303, DiffTime : 34ms
# 2024-06-19 11:13:55.267
# [iso : 150] [shutter : 1/6000.0] [fnum : 170] [ev : 0] [ct : 4941] [color_md : default] [focal_len : 240] [dzoom_ratio: 10000, delta:0],[latitude: 32.105677] [longitude: 35.206631] [rel_alt: 117.500 abs_alt: 802.541] </font>
# Parsing line: <font size="28">SrtCnt : 22304, DiffTime : 33ms
# 2024-06-19 11:13:55.300
# [iso : 150] [shutter : 1/6000.0] [fnum : 170] [ev : 0] [ct : 4938] [color_md : default] [focal_len : 240] [dzoom_ratio: 10000, delta:0],[latitude: 32.105677] [longitude: 35.206631] [rel_alt: 117.500 abs_alt: 802.541] </font>
# Parsing line: <font size="28">SrtCnt : 22305, DiffTime : 33ms
# 2024-06-19 11:13:55.334
# [iso : 150] [shutter : 1/6000.0] [fnum : 170] [ev : 0] [ct : 4938] [color_md : default] [focal_len : 240] [dzoom_ratio: 10000, delta:0],[latitude: 32.105685] [longitude: 35.206635] [rel_alt: 117.500 abs_alt: 802.541] </font>
# Parsing line: <font size="28">SrtCnt : 22306, DiffTime : 34ms
# 2024-06-19 11:13:55.367
# [iso : 150] [shutter : 1/6000.0] [fnum : 170] [ev : 0] [ct : 4935] [color_md : default] [focal_len : 240] [dzoom_ratio: 10000, delta:0],[latitude: 32.105685] [longitude: 35.206635] [rel_alt: 117.500 abs_alt: 802.541] </font>
# Parsing line: <font size="28">SrtCnt : 22307, DiffTime : 33ms
# 2024-06-19 11:13:55.400
# [iso : 150] [shutter : 1/6000.0] [fnum : 170] [ev : 0] [ct : 4935] [color_md : default] [focal_len : 240] [dzoom_ratio: 10000, delta:0],[latitude: 32.105685] [longitude: 35.206635] [rel_alt: 117.500 abs_alt: 802.541] </font>
# Parsing line: <font size="28">SrtCnt : 22308, DiffTime : 34ms
# 2024-06-19 11:13:55.433
# [iso : 150] [shutter : 1/6000.0] [fnum : 170] [ev : 0] [ct : 4932] [color_md : default] [focal_len : 240] [dzoom_ratio: 10000, delta:0],[latitude: 32.105693] [longitude: 35.206640] [rel_alt: 117.500 abs_alt: 802.541] </font>
# Parsing line: <font size="28">SrtCnt : 22309, DiffTime : 33ms
# 2024-06-19 11:13:55.467
# [iso : 150] [shutter : 1/6000.0] [fnum : 170] [ev : 0] [ct : 4932] [color_md : default] [focal_len : 240] [dzoom_ratio: 10000, delta:0],[latitude: 32.105693] [longitude: 35.206640] [rel_alt: 117.500 abs_alt: 802.541] </font>
# Parsing line: <font size="28">SrtCnt : 22310, DiffTime : 33ms
# 2024-06-19 11:13:55.500
# [iso : 150] [shutter : 1/6000.0] [fnum : 170] [ev : 0] [ct : 4930] [color_md : default] [focal_len : 240] [dzoom_ratio: 10000, delta:0],[latitude: 32.105693] [longitude: 35.206640] [rel_alt: 117.500 abs_alt: 802.541] </font>
# Parsing line: <font size="28">SrtCnt : 22311, DiffTime : 34ms
# 2024-06-19 11:13:55.533
# [iso : 150] [shutter : 1/6000.0] [fnum : 170] [ev : 0] [ct : 4930] [color_md : default] [focal_len : 240] [dzoom_ratio: 10000, delta:0],[latitude: 32.105701] [longitude: 35.206644] [rel_alt: 117.500 abs_alt: 802.541] </font>
# Parsing line: <font size="28">SrtCnt : 22312, DiffTime : 33ms
# 2024-06-19 11:13:55.567
# [iso : 150] [shutter : 1/6000.0] [fnum : 170] [ev : 0] [ct : 4927] [color_md : default] [focal_len : 240] [dzoom_ratio: 10000, delta:0],[latitude: 32.105701] [longitude: 35.206644] [rel_alt: 117.500 abs_alt: 802.541] </font>
# Parsing line: <font size="28">SrtCnt : 22313, DiffTime : 33ms
# 2024-06-19 11:13:55.600
# [iso : 150] [shutter : 1/6000.0] [fnum : 170] [ev : 0] [ct : 4927] [color_md : default] [focal_len : 240] [dzoom_ratio: 10000, delta:0],[latitude: 32.105701] [longitude: 35.206644] [rel_alt: 117.500 abs_alt: 802.541] </font>
# Parsing line: <font size="28">SrtCnt : 22314, DiffTime : 34ms
# 2024-06-19 11:13:55.634
# [iso : 150] [shutter : 1/6000.0] [fnum : 170] [ev : 0] [ct : 4924] [color_md : default] [focal_len : 240] [dzoom_ratio: 10000, delta:0],[latitude: 32.105710] [longitude: 35.206648] [rel_alt: 117.500 abs_alt: 802.541] </font>
# Parsing line: <font size="28">SrtCnt : 22315, DiffTime : 33ms
# 2024-06-19 11:13:55.667
# [iso : 150] [shutter : 1/6000.0] [fnum : 170] [ev : 0] [ct : 4924] [color_md : default] [focal_len : 240] [dzoom_ratio: 10000, delta:0],[latitude: 32.105710] [longitude: 35.206648] [rel_alt: 117.500 abs_alt: 802.541] </font>
# Parsing line: <font size="28">SrtCnt : 22316, DiffTime : 33ms
# 2024-06-19 11:13:55.700
# [iso : 150] [shutter : 1/6000.0] [fnum : 170] [ev : 0] [ct : 4920] [color_md : default] [focal_len : 240] [dzoom_ratio: 10000, delta:0],[latitude: 32.105710] [longitude: 35.206648] [rel_alt: 117.500 abs_alt: 802.541] </font>
# Parsing line: <font size="28">SrtCnt : 22317, DiffTime : 34ms
# 2024-06-19 11:13:55.734
# [iso : 150] [shutter : 1/6000.0] [fnum : 170] [ev : 0] [ct : 4920] [color_md : default] [focal_len : 240] [dzoom_ratio: 10000, delta:0],[latitude: 32.105718] [longitude: 35.206652] [rel_alt: 117.500 abs_alt: 802.541] </font>
# Parsing line: <font size="28">SrtCnt : 22318, DiffTime : 33ms
# 2024-06-19 11:13:55.767
# [iso : 150] [shutter : 1/6000.0] [fnum : 170] [ev : 0] [ct : 4917] [color_md : default] [focal_len : 240] [dzoom_ratio: 10000, delta:0],[latitude: 32.105718] [longitude: 35.206652] [rel_alt: 117.500 abs_alt: 802.541] </font>
# Parsing line: <font size="28">SrtCnt : 22319, DiffTime : 34ms
# 2024-06-19 11:13:55.800
# [iso : 150] [shutter : 1/6000.0] [fnum : 170] [ev : 0] [ct : 4917] [color_md : default] [focal_len : 240] [dzoom_ratio: 10000, delta:0],[latitude: 32.105718] [longitude: 35.206652] [rel_alt: 117.500 abs_alt: 802.541] </font>
# Parsing line: <font size="28">SrtCnt : 22320, DiffTime : 33ms
# 2024-06-19 11:13:55.835
# [iso : 150] [shutter : 1/6000.0] [fnum : 170] [ev : 0] [ct : 4913] [color_md : default] [focal_len : 240] [dzoom_ratio: 10000, delta:0],[latitude: 32.105726] [longitude: 35.206657] [rel_alt: 117.600 abs_alt: 802.641] </font>
# Parsing line: <font size="28">SrtCnt : 22321, DiffTime : 33ms
# 2024-06-19 11:13:55.867
# [iso : 150] [shutter : 1/6000.0] [fnum : 170] [ev : 0] [ct : 4913] [color_md : default] [focal_len : 240] [dzoom_ratio: 10000, delta:0],[latitude: 32.105726] [longitude: 35.206657] [rel_alt: 117.600 abs_alt: 802.641] </font>
# Parsing line: <font size="28">SrtCnt : 22322, DiffTime : 34ms
# 2024-06-19 11:13:55.900
# [iso : 150] [shutter : 1/6000.0] [fnum : 170] [ev : 0] [ct : 4909] [color_md : default] [focal_len : 240] [dzoom_ratio: 10000, delta:0],[latitude: 32.105726] [longitude: 35.206657] [rel_alt: 117.600 abs_alt: 802.641] </font>
# Parsing line: <font size="28">SrtCnt : 22323, DiffTime : 33ms
# 2024-06-19 11:13:55.933
# [iso : 150] [shutter : 1/6000.0] [fnum : 170] [ev : 0] [ct : 4909] [color_md : default] [focal_len : 240] [dzoom_ratio: 10000, delta:0],[latitude: 32.105733] [longitude: 35.206661] [rel_alt: 117.600 abs_alt: 802.641] </font>
# Parsing line: <font size="28">SrtCnt : 22324, DiffTime : 33ms
# 2024-06-19 11:13:55.967
# [iso : 150] [shutter : 1/6000.0] [fnum : 170] [ev : 0] [ct : 4909] [color_md : default] [focal_len : 240] [dzoom_ratio: 10000, delta:0],[latitude: 32.105733] [longitude: 35.206661] [rel_alt: 117.600 abs_alt: 802.641] </font>
# Parsing line: <font size="28">SrtCnt : 22325, DiffTime : 34ms
# 2024-06-19 11:13:56.000
# [iso : 150] [shutter : 1/6000.0] [fnum : 170] [ev : 0] [ct : 4904] [color_md : default] [focal_len : 240] [dzoom_ratio: 10000, delta:0],[latitude: 32.105733] [longitude: 35.206661] [rel_alt: 117.600 abs_alt: 802.641] </font>
# Parsing line: <font size="28">SrtCnt : 22326, DiffTime : 33ms
# 2024-06-19 11:13:56.033
# [iso : 150] [shutter : 1/6000.0] [fnum : 170] [ev : 0] [ct : 4904] [color_md : default] [focal_len : 240] [dzoom_ratio: 10000, delta:0],[latitude: 32.105741] [longitude: 35.206666] [rel_alt: 117.600 abs_alt: 802.641] </font>
# Parsing line: <font size="28">SrtCnt : 22327, DiffTime : 33ms
# 2024-06-19 11:13:56.067
# [iso : 150] [shutter : 1/6000.0] [fnum : 170] [ev : 0] [ct : 4900] [color_md : default] [focal_len : 240] [dzoom_ratio: 10000, delta:0],[latitude: 32.105741] [longitude: 35.206666] [rel_alt: 117.600 abs_alt: 802.641] </font>
# Parsing line: <font size="28">SrtCnt : 22328, DiffTime : 34ms
# 2024-06-19 11:13:56.100
# [iso : 150] [shutter : 1/6000.0] [fnum : 170] [ev : 0] [ct : 4900] [color_md : default] [focal_len : 240] [dzoom_ratio: 10000, delta:0],[latitude: 32.105741] [longitude: 35.206666] [rel_alt: 117.600 abs_alt: 802.641] </font>
# Parsing line: <font size="28">SrtCnt : 22329, DiffTime : 33ms
# 2024-06-19 11:13:56.134
# [iso : 150] [shutter : 1/6000.0] [fnum : 170] [ev : 0] [ct : 4895] [color_md : default] [focal_len : 240] [dzoom_ratio: 10000, delta:0],[latitude: 32.105749] [longitude: 35.206671] [rel_alt: 117.500 abs_alt: 802.541] </font>
# Parsing line: <font size="28">SrtCnt : 22330, DiffTime : 34ms
# 2024-06-19 11:13:56.167
# [iso : 150] [shutter : 1/6000.0] [fnum : 170] [ev : 0] [ct : 4895] [color_md : default] [focal_len : 240] [dzoom_ratio: 10000, delta:0],[latitude: 32.105749] [longitude: 35.206671] [rel_alt: 117.500 abs_alt: 802.541] </font>
# Parsing line: <font size="28">SrtCnt : 22331, DiffTime : 33ms
# 2024-06-19 11:13:56.200
# [iso : 150] [shutter : 1/6000.0] [fnum : 170] [ev : 0] [ct : 4890] [color_md : default] [focal_len : 240] [dzoom_ratio: 10000, delta:0],[latitude: 32.105749] [longitude: 35.206671] [rel_alt: 117.500 abs_alt: 802.541] </font>
# Parsing line: <font size="28">SrtCnt : 22332, DiffTime : 33ms
# 2024-06-19 11:13:56.234
# [iso : 150] [shutter : 1/6000.0] [fnum : 170] [ev : 0] [ct : 4890] [color_md : default] [focal_len : 240] [dzoom_ratio: 10000, delta:0],[latitude: 32.105757] [longitude: 35.206676] [rel_alt: 117.500 abs_alt: 802.541] </font>
# Parsing line: <font size="28">SrtCnt : 22333, DiffTime : 34ms
# 2024-06-19 11:13:56.267
# [iso : 150] [shutter : 1/6000.0] [fnum : 170] [ev : 0] [ct : 4886] [color_md : default] [focal_len : 240] [dzoom_ratio: 10000, delta:0],[latitude: 32.105757] [longitude: 35.206676] [rel_alt: 117.500 abs_alt: 802.541] </font>
# Parsing line: <font size="28">SrtCnt : 22334, DiffTime : 33ms
# 2024-06-19 11:13:56.301
# [iso : 150] [shutter : 1/6000.0] [fnum : 170] [ev : 0] [ct : 4886] [color_md : default] [focal_len : 240] [dzoom_ratio: 10000, delta:0],[latitude: 32.105757] [longitude: 35.206676] [rel_alt: 117.500 abs_alt: 802.541] </font>
# Parsing line: <font size="28">SrtCnt : 22335, DiffTime : 33ms
# 2024-06-19 11:13:56.334
# [iso : 150] [shutter : 1/6000.0] [fnum : 170] [ev : 0] [ct : 4881] [color_md : default] [focal_len : 240] [dzoom_ratio: 10000, delta:0],[latitude: 32.105764] [longitude: 35.206681] [rel_alt: 117.500 abs_alt: 802.541] </font>
# Parsing line: <font size="28">SrtCnt : 22336, DiffTime : 34ms
# 2024-06-19 11:13:56.367
# [iso : 150] [shutter : 1/6000.0] [fnum : 170] [ev : 0] [ct : 4881] [color_md : default] [focal_len : 240] [dzoom_ratio: 10000, delta:0],[latitude: 32.105764] [longitude: 35.206681] [rel_alt: 117.500 abs_alt: 802.541] </font>
# Parsing line: <font size="28">SrtCnt : 22337, DiffTime : 33ms
# 2024-06-19 11:13:56.401
# [iso : 150] [shutter : 1/6000.0] [fnum : 170] [ev : 0] [ct : 4877] [color_md : default] [focal_len : 240] [dzoom_ratio: 10000, delta:0],[latitude: 32.105764] [longitude: 35.206681] [rel_alt: 117.500 abs_alt: 802.541] </font>
# Parsing line: <font size="28">SrtCnt : 22338, DiffTime : 33ms
# 2024-06-19 11:13:56.435
# [iso : 150] [shutter : 1/6000.0] [fnum : 170] [ev : 0] [ct : 4877] [color_md : default] [focal_len : 240] [dzoom_ratio: 10000, delta:0],[latitude: 32.105772] [longitude: 35.206687] [rel_alt: 117.500 abs_alt: 802.541] </font>
# Parsing line: <font size="28">SrtCnt : 22339, DiffTime : 34ms
# 2024-06-19 11:13:56.468
# [iso : 150] [shutter : 1/6000.0] [fnum : 170] [ev : 0] [ct : 4874] [color_md : default] [focal_len : 240] [dzoom_ratio: 10000, delta:0],[latitude: 32.105772] [longitude: 35.206687] [rel_alt: 117.500 abs_alt: 802.541] </font>
# Parsing line: <font size="28">SrtCnt : 22340, DiffTime : 33ms
# 2024-06-19 11:13:56.501
# [iso : 150] [shutter : 1/6000.0] [fnum : 170] [ev : 0] [ct : 4874] [color_md : default] [focal_len : 240] [dzoom_ratio: 10000, delta:0],[latitude: 32.105772] [longitude: 35.206687] [rel_alt: 117.500 abs_alt: 802.541] </font>
# Parsing line: <font size="28">SrtCnt : 22341, DiffTime : 34ms
# 2024-06-19 11:13:56.534
# [iso : 150] [shutter : 1/6000.0] [fnum : 170] [ev : 0] [ct : 4870] [color_md : default] [focal_len : 240] [dzoom_ratio: 10000, delta:0],[latitude: 32.105779] [longitude: 35.206692] [rel_alt: 117.500 abs_alt: 802.541] </font>
# Parsing line: <font size="28">SrtCnt : 22342, DiffTime : 33ms
# 2024-06-19 11:13:56.568
# [iso : 150] [shutter : 1/6000.0] [fnum : 170] [ev : 0] [ct : 4870] [color_md : default] [focal_len : 240] [dzoom_ratio: 10000, delta:0],[latitude: 32.105779] [longitude: 35.206692] [rel_alt: 117.500 abs_alt: 802.541] </font>
# Parsing line: <font size="28">SrtCnt : 22343, DiffTime : 33ms
# 2024-06-19 11:13:56.601
# [iso : 150] [shutter : 1/6000.0] [fnum : 170] [ev : 0] [ct : 4867] [color_md : default] [focal_len : 240] [dzoom_ratio: 10000, delta:0],[latitude: 32.105779] [longitude: 35.206692] [rel_alt: 117.500 abs_alt: 802.541] </font>
# Parsing line: <font size="28">SrtCnt : 22344, DiffTime : 34ms
# 2024-06-19 11:13:56.634
# [iso : 150] [shutter : 1/6000.0] [fnum : 170] [ev : 0] [ct : 4867] [color_md : default] [focal_len : 240] [dzoom_ratio: 10000, delta:0],[latitude: 32.105787] [longitude: 35.206698] [rel_alt: 117.500 abs_alt: 802.541] </font>
# Parsing line: <font size="28">SrtCnt : 22345, DiffTime : 33ms
# 2024-06-19 11:13:56.668
# [iso : 150] [shutter : 1/6000.0] [fnum : 170] [ev : 0] [ct : 4864] [color_md : default] [focal_len : 240] [dzoom_ratio: 10000, delta:0],[latitude: 32.105787] [longitude: 35.206698] [rel_alt: 117.500 abs_alt: 802.541] </font>
# Parsing line: <font size="28">SrtCnt : 22346, DiffTime : 33ms
# 2024-06-19 11:13:56.701
# [iso : 150] [shutter : 1/6000.0] [fnum : 170] [ev : 0] [ct : 4864] [color_md : default] [focal_len : 240] [dzoom_ratio: 10000, delta:0],[latitude: 32.105787] [longitude: 35.206698] [rel_alt: 117.500 abs_alt: 802.541] </font>
# Parsing line: <font size="28">SrtCnt : 22347, DiffTime : 34ms
# 2024-06-19 11:13:56.734
# [iso : 150] [shutter : 1/6000.0] [fnum : 170] [ev : 0] [ct : 4864] [color_md : default] [focal_len : 240] [dzoom_ratio: 10000, delta:0],[latitude: 32.105794] [longitude: 35.206703] [rel_alt: 117.500 abs_alt: 802.541] </font>
# Parsing line: <font size="28">SrtCnt : 22348, DiffTime : 33ms
# 2024-06-19 11:13:56.768
# [iso : 150] [shutter : 1/6000.0] [fnum : 170] [ev : 0] [ct : 4861] [color_md : default] [focal_len : 240] [dzoom_ratio: 10000, delta:0],[latitude: 32.105794] [longitude: 35.206703] [rel_alt: 117.500 abs_alt: 802.541] </font>
# Parsing line: <font size="28">SrtCnt : 22349, DiffTime : 33ms
# 2024-06-19 11:13:56.801
# [iso : 150] [shutter : 1/6000.0] [fnum : 170] [ev : 0] [ct : 4861] [color_md : default] [focal_len : 240] [dzoom_ratio: 10000, delta:0],[latitude: 32.105794] [longitude: 35.206703] [rel_alt: 117.500 abs_alt: 802.541] </font>
# Parsing line: <font size="28">SrtCnt : 22350, DiffTime : 34ms
# 2024-06-19 11:13:56.834
# [iso : 150] [shutter : 1/6000.0] [fnum : 170] [ev : 0] [ct : 4859] [color_md : default] [focal_len : 240] [dzoom_ratio: 10000, delta:0],[latitude: 32.105802] [longitude: 35.206709] [rel_alt: 117.500 abs_alt: 802.541] </font>
# Parsing line: <font size="28">SrtCnt : 22351, DiffTime : 33ms
# 2024-06-19 11:13:56.868
# [iso : 150] [shutter : 1/6000.0] [fnum : 170] [ev : 0] [ct : 4859] [color_md : default] [focal_len : 240] [dzoom_ratio: 10000, delta:0],[latitude: 32.105802] [longitude: 35.206709] [rel_alt: 117.500 abs_alt: 802.541] </font>
# Parsing line: <font size="28">SrtCnt : 22352, DiffTime : 34ms
# 2024-06-19 11:13:56.901
# [iso : 150] [shutter : 1/6000.0] [fnum : 170] [ev : 0] [ct : 4856] [color_md : default] [focal_len : 240] [dzoom_ratio: 10000, delta:0],[latitude: 32.105802] [longitude: 35.206709] [rel_alt: 117.500 abs_alt: 802.541] </font>
# Parsing line: <font size="28">SrtCnt : 22353, DiffTime : 33ms
# 2024-06-19 11:13:56.935
# [iso : 150] [shutter : 1/6000.0] [fnum : 170] [ev : 0] [ct : 4856] [color_md : default] [focal_len : 240] [dzoom_ratio: 10000, delta:0],[latitude: 32.105809] [longitude: 35.206715] [rel_alt: 117.500 abs_alt: 802.541] </font>
# Parsing line: <font size="28">SrtCnt : 22354, DiffTime : 33ms
# 2024-06-19 11:13:56.968
# [iso : 150] [shutter : 1/6000.0] [fnum : 170] [ev : 0] [ct : 4854] [color_md : default] [focal_len : 240] [dzoom_ratio: 10000, delta:0],[latitude: 32.105809] [longitude: 35.206715] [rel_alt: 117.500 abs_alt: 802.541] </font>
# Parsing line: <font size="28">SrtCnt : 22355, DiffTime : 34ms
# 2024-06-19 11:13:57.001
# [iso : 150] [shutter : 1/6000.0] [fnum : 170] [ev : 0] [ct : 4854] [color_md : default] [focal_len : 240] [dzoom_ratio: 10000, delta:0],[latitude: 32.105809] [longitude: 35.206715] [rel_alt: 117.500 abs_alt: 802.541] </font>
# Parsing line: <font size="28">SrtCnt : 22356, DiffTime : 33ms
# 2024-06-19 11:13:57.034
# [iso : 150] [shutter : 1/6000.0] [fnum : 170] [ev : 0] [ct : 4852] [color_md : default] [focal_len : 240] [dzoom_ratio: 10000, delta:0],[latitude: 32.105816] [longitude: 35.206720] [rel_alt: 117.500 abs_alt: 802.541] </font>
# Parsing line: <font size="28">SrtCnt : 22357, DiffTime : 33ms
# 2024-06-19 11:13:57.068
# [iso : 150] [shutter : 1/6000.0] [fnum : 170] [ev : 0] [ct : 4852] [color_md : default] [focal_len : 240] [dzoom_ratio: 10000, delta:0],[latitude: 32.105816] [longitude: 35.206720] [rel_alt: 117.500 abs_alt: 802.541] </font>
# Parsing line: <font size="28">SrtCnt : 22358, DiffTime : 34ms
# 2024-06-19 11:13:57.101
# [iso : 150] [shutter : 1/6000.0] [fnum : 170] [ev : 0] [ct : 4850] [color_md : default] [focal_len : 240] [dzoom_ratio: 10000, delta:0],[latitude: 32.105816] [longitude: 35.206720] [rel_alt: 117.500 abs_alt: 802.541] </font>
# Parsing line: <font size="28">SrtCnt : 22359, DiffTime : 33ms
# 2024-06-19 11:13:57.135
# [iso : 150] [shutter : 1/6000.0] [fnum : 170] [ev : 0] [ct : 4850] [color_md : default] [focal_len : 240] [dzoom_ratio: 10000, delta:0],[latitude: 32.105824] [longitude: 35.206726] [rel_alt: 117.500 abs_alt: 802.541] </font>
# Parsing line: <font size="28">SrtCnt : 22360, DiffTime : 33ms
# 2024-06-19 11:13:57.168
# [iso : 150] [shutter : 1/6000.0] [fnum : 170] [ev : 0] [ct : 4848] [color_md : default] [focal_len : 240] [dzoom_ratio: 10000, delta:0],[latitude: 32.105824] [longitude: 35.206726] [rel_alt: 117.500 abs_alt: 802.541] </font>
# Parsing line: <font size="28">SrtCnt : 22361, DiffTime : 34ms
# 2024-06-19 11:13:57.201
# [iso : 150] [shutter : 1/6000.0] [fnum : 170] [ev : 0] [ct : 4848] [color_md : default] [focal_len : 240] [dzoom_ratio: 10000, delta:0],[latitude: 32.105824] [longitude: 35.206726] [rel_alt: 117.500 abs_alt: 802.541] </font>
# Parsing line: <font size="28">SrtCnt : 22362, DiffTime : 33ms
# 2024-06-19 11:13:57.235
# [iso : 150] [shutter : 1/6000.0] [fnum : 170] [ev : 0] [ct : 4848] [color_md : default] [focal_len : 240] [dzoom_ratio: 10000, delta:0],[latitude: 32.105831] [longitude: 35.206732] [rel_alt: 117.500 abs_alt: 802.541] </font>
# Parsing line: <font size="28">SrtCnt : 22363, DiffTime : 34ms
# 2024-06-19 11:13:57.268
# [iso : 150] [shutter : 1/6000.0] [fnum : 170] [ev : 0] [ct : 4846] [color_md : default] [focal_len : 240] [dzoom_ratio: 10000, delta:0],[latitude: 32.105831] [longitude: 35.206732] [rel_alt: 117.500 abs_alt: 802.541] </font>
# Parsing line: <font size="28">SrtCnt : 22364, DiffTime : 33ms
# 2024-06-19 11:13:57.302
# [iso : 150] [shutter : 1/6000.0] [fnum : 170] [ev : 0] [ct : 4846] [color_md : default] [focal_len : 240] [dzoom_ratio: 10000, delta:0],[latitude: 32.105831] [longitude: 35.206732] [rel_alt: 117.500 abs_alt: 802.541] </font>
# Parsing line: <font size="28">SrtCnt : 22365, DiffTime : 33ms
# 2024-06-19 11:13:57.335
# [iso : 150] [shutter : 1/6000.0] [fnum : 170] [ev : 0] [ct : 4845] [color_md : default] [focal_len : 240] [dzoom_ratio: 10000, delta:0],[latitude: 32.105839] [longitude: 35.206738] [rel_alt: 117.500 abs_alt: 802.541] </font>
# Parsing line: <font size="28">SrtCnt : 22366, DiffTime : 34ms
# 2024-06-19 11:13:57.368
# [iso : 150] [shutter : 1/6000.0] [fnum : 170] [ev : 0] [ct : 4845] [color_md : default] [focal_len : 240] [dzoom_ratio: 10000, delta:0],[latitude: 32.105839] [longitude: 35.206738] [rel_alt: 117.500 abs_alt: 802.541] </font>
# Parsing line: <font size="28">SrtCnt : 22367, DiffTime : 33ms
# 2024-06-19 11:13:57.402
# [iso : 150] [shutter : 1/6000.0] [fnum : 170] [ev : 0] [ct : 4843] [color_md : default] [focal_len : 240] [dzoom_ratio: 10000, delta:0],[latitude: 32.105839] [longitude: 35.206738] [rel_alt: 117.500 abs_alt: 802.541] </font>
# Parsing line: <font size="28">SrtCnt : 22368, DiffTime : 33ms
# 2024-06-19 11:13:57.435
# [iso : 150] [shutter : 1/6000.0] [fnum : 170] [ev : 0] [ct : 4843] [color_md : default] [focal_len : 240] [dzoom_ratio: 10000, delta:0],[latitude: 32.105846] [longitude: 35.206744] [rel_alt: 117.500 abs_alt: 802.541] </font>
# Parsing line: <font size="28">SrtCnt : 22369, DiffTime : 34ms
# 2024-06-19 11:13:57.468
# [iso : 150] [shutter : 1/6000.0] [fnum : 170] [ev : 0] [ct : 4841] [color_md : default] [focal_len : 240] [dzoom_ratio: 10000, delta:0],[latitude: 32.105846] [longitude: 35.206744] [rel_alt: 117.500 abs_alt: 802.541] </font>
# Parsing line: <font size="28">SrtCnt : 22370, DiffTime : 33ms
# 2024-06-19 11:13:57.502
# [iso : 160] [shutter : 1/6000.0] [fnum : 170] [ev : 0] [ct : 4841] [color_md : default] [focal_len : 240] [dzoom_ratio: 10000, delta:0],[latitude: 32.105846] [longitude: 35.206744] [rel_alt: 117.500 abs_alt: 802.541] </font>
# Parsing line: <font size="28">SrtCnt : 22371, DiffTime : 33ms
# 2024-06-19 11:13:57.535
# [iso : 160] [shutter : 1/6000.0] [fnum : 170] [ev : 0] [ct : 4839] [color_md : default] [focal_len : 240] [dzoom_ratio: 10000, delta:0],[latitude: 32.105853] [longitude: 35.206750] [rel_alt: 117.500 abs_alt: 802.541] </font>
# Parsing line: <font size="28">SrtCnt : 22372, DiffTime : 34ms
# 2024-06-19 11:13:57.569
# [iso : 160] [shutter : 1/6000.0] [fnum : 170] [ev : 0] [ct : 4839] [color_md : default] [focal_len : 240] [dzoom_ratio: 10000, delta:0],[latitude: 32.105853] [longitude: 35.206750] [rel_alt: 117.500 abs_alt: 802.541] </font>
# Parsing line: <font size="28">SrtCnt : 22373, DiffTime : 33ms
# 2024-06-19 11:13:57.602
# [iso : 160] [shutter : 1/6000.0] [fnum : 170] [ev : 0] [ct : 4838] [color_md : default] [focal_len : 240] [dzoom_ratio: 10000, delta:0],[latitude: 32.105853] [longitude: 35.206750] [rel_alt: 117.500 abs_alt: 802.541] </font>
# Parsing line: <font size="28">SrtCnt : 22374, DiffTime : 33ms
# 2024-06-19 11:13:57.635
# [iso : 160] [shutter : 1/6000.0] [fnum : 170] [ev : 0] [ct : 4838] [color_md : default] [focal_len : 240] [dzoom_ratio: 10000, delta:0],[latitude: 32.105861] [longitude: 35.206756] [rel_alt: 117.500 abs_alt: 802.541] </font>
# Parsing line: <font size="28">SrtCnt : 22375, DiffTime : 34ms
# 2024-06-19 11:13:57.669
# [iso : 160] [shutter : 1/6000.0] [fnum : 170] [ev : 0] [ct : 4836] [color_md : default] [focal_len : 240] [dzoom_ratio: 10000, delta:0],[latitude: 32.105861] [longitude: 35.206756] [rel_alt: 117.500 abs_alt: 802.541] </font>
# Parsing line: <font size="28">SrtCnt : 22376, DiffTime : 33ms
# 2024-06-19 11:13:57.702
# [iso : 160] [shutter : 1/6000.0] [fnum : 170] [ev : 0] [ct : 4836] [color_md : default] [focal_len : 240] [dzoom_ratio: 10000, delta:0],[latitude: 32.105861] [longitude: 35.206756] [rel_alt: 117.500 abs_alt: 802.541] </font>
# Parsing line: <font size="28">SrtCnt : 22377, DiffTime : 34ms
# 2024-06-19 11:13:57.735
# [iso : 160] [shutter : 1/6000.0] [fnum : 170] [ev : 0] [ct : 4835] [color_md : default] [focal_len : 240] [dzoom_ratio: 10000, delta:0],[latitude: 32.105868] [longitude: 35.206761] [rel_alt: 117.500 abs_alt: 802.541] </font>
# Parsing line: <font size="28">SrtCnt : 22378, DiffTime : 33ms
# 2024-06-19 11:13:57.769
# [iso : 160] [shutter : 1/6000.0] [fnum : 170] [ev : 0] [ct : 4835] [color_md : default] [focal_len : 240] [dzoom_ratio: 10000, delta:0],[latitude: 32.105868] [longitude: 35.206761] [rel_alt: 117.500 abs_alt: 802.541] </font>
# Parsing line: <font size="28">SrtCnt : 22379, DiffTime : 33ms
# 2024-06-19 11:13:57.802
# [iso : 160] [shutter : 1/6000.0] [fnum : 170] [ev : 0] [ct : 4833] [color_md : default] [focal_len : 240] [dzoom_ratio: 10000, delta:0],[latitude: 32.105868] [longitude: 35.206761] [rel_alt: 117.500 abs_alt: 802.541] </font>
# Parsing line: <font size="28">SrtCnt : 22380, DiffTime : 34ms
# 2024-06-19 11:13:57.835
# [iso : 160] [shutter : 1/6000.0] [fnum : 170] [ev : 0] [ct : 4833] [color_md : default] [focal_len : 240] [dzoom_ratio: 10000, delta:0],[latitude: 32.105876] [longitude: 35.206768] [rel_alt: 117.500 abs_alt: 802.541] </font>
# Parsing line: <font size="28">SrtCnt : 22381, DiffTime : 33ms
# 2024-06-19 11:13:57.869
# [iso : 160] [shutter : 1/6000.0] [fnum : 170] [ev : 0] [ct : 4831] [color_md : default] [focal_len : 240] [dzoom_ratio: 10000, delta:0],[latitude: 32.105876] [longitude: 35.206768] [rel_alt: 117.500 abs_alt: 802.541] </font>
# Parsing line: <font size="28">SrtCnt : 22382, DiffTime : 33ms
# 2024-06-19 11:13:57.902
# [iso : 160] [shutter : 1/6000.0] [fnum : 170] [ev : 0] [ct : 4831] [color_md : default] [focal_len : 240] [dzoom_ratio: 10000, delta:0],[latitude: 32.105876] [longitude: 35.206768] [rel_alt: 117.500 abs_alt: 802.541] </font>
# Parsing line: <font size="28">SrtCnt : 22383, DiffTime : 34ms
# 2024-06-19 11:13:57.935
# [iso : 160] [shutter : 1/6000.0] [fnum : 170] [ev : 0] [ct : 4830] [color_md : default] [focal_len : 240] [dzoom_ratio: 10000, delta:0],[latitude: 32.105883] [longitude: 35.206773] [rel_alt: 117.500 abs_alt: 802.541] </font>
# Parsing line: <font size="28">SrtCnt : 22384, DiffTime : 33ms
# 2024-06-19 11:13:57.969
# [iso : 160] [shutter : 1/6000.0] [fnum : 170] [ev : 0] [ct : 4830] [color_md : default] [focal_len : 240] [dzoom_ratio: 10000, delta:0],[latitude: 32.105883] [longitude: 35.206773] [rel_alt: 117.500 abs_alt: 802.541] </font>
# Parsing line: <font size="28">SrtCnt : 22385, DiffTime : 33ms
# 2024-06-19 11:13:58.002
# [iso : 160] [shutter : 1/6000.0] [fnum : 170] [ev : 0] [ct : 4828] [color_md : default] [focal_len : 240] [dzoom_ratio: 10000, delta:0],[latitude: 32.105883] [longitude: 35.206773] [rel_alt: 117.500 abs_alt: 802.541] </font>
# Parsing line: <font size="28">SrtCnt : 22386, DiffTime : 34ms
# 2024-06-19 11:13:58.035
# [iso : 160] [shutter : 1/6000.0] [fnum : 170] [ev : 0] [ct : 4828] [color_md : default] [focal_len : 240] [dzoom_ratio: 10000, delta:0],[latitude: 32.105890] [longitude: 35.206779] [rel_alt: 117.500 abs_alt: 802.541] </font>
# Parsing line: <font size="28">SrtCnt : 22387, DiffTime : 33ms
# 2024-06-19 11:13:58.069
# [iso : 160] [shutter : 1/6000.0] [fnum : 170] [ev : 0] [ct : 4827] [color_md : default] [focal_len : 240] [dzoom_ratio: 10000, delta:0],[latitude: 32.105890] [longitude: 35.206779] [rel_alt: 117.500 abs_alt: 802.541] </font>
# Parsing line: <font size="28">SrtCnt : 22388, DiffTime : 34ms
# 2024-06-19 11:13:58.102
# [iso : 160] [shutter : 1/6000.0] [fnum : 170] [ev : 0] [ct : 4827] [color_md : default] [focal_len : 240] [dzoom_ratio: 10000, delta:0],[latitude: 32.105890] [longitude: 35.206779] [rel_alt: 117.500 abs_alt: 802.541] </font>
# Parsing line: <font size="28">SrtCnt : 22389, DiffTime : 33ms
# 2024-06-19 11:13:58.135
# [iso : 160] [shutter : 1/6000.0] [fnum : 170] [ev : 0] [ct : 4826] [color_md : default] [focal_len : 240] [dzoom_ratio: 10000, delta:0],[latitude: 32.105898] [longitude: 35.206785] [rel_alt: 117.500 abs_alt: 802.541] </font>
# Parsing line: <font size="28">SrtCnt : 22390, DiffTime : 33ms
# 2024-06-19 11:13:58.169
# [iso : 160] [shutter : 1/6000.0] [fnum : 170] [ev : 0] [ct : 4826] [color_md : default] [focal_len : 240] [dzoom_ratio: 10000, delta:0],[latitude: 32.105898] [longitude: 35.206785] [rel_alt: 117.500 abs_alt: 802.541] </font>
# Parsing line: <font size="28">SrtCnt : 22391, DiffTime : 34ms
# 2024-06-19 11:13:58.202
# [iso : 160] [shutter : 1/6000.0] [fnum : 170] [ev : 0] [ct : 4825] [color_md : default] [focal_len : 240] [dzoom_ratio: 10000, delta:0],[latitude: 32.105898] [longitude: 35.206785] [rel_alt: 117.500 abs_alt: 802.541] </font>
# Parsing line: <font size="28">SrtCnt : 22392, DiffTime : 33ms
# 2024-06-19 11:13:58.236
# [iso : 160] [shutter : 1/6000.0] [fnum : 170] [ev : 0] [ct : 4825] [color_md : default] [focal_len : 240] [dzoom_ratio: 10000, delta:0],[latitude: 32.105905] [longitude: 35.206791] [rel_alt: 117.500 abs_alt: 802.541] </font>
# Parsing line: <font size="28">SrtCnt : 22393, DiffTime : 33ms
# 2024-06-19 11:13:58.269
# [iso : 160] [shutter : 1/6000.0] [fnum : 170] [ev : 0] [ct : 4824] [color_md : default] [focal_len : 240] [dzoom_ratio: 10000, delta:0],[latitude: 32.105905] [longitude: 35.206791] [rel_alt: 117.500 abs_alt: 802.541] </font>
# Parsing line: <font size="28">SrtCnt : 22394, DiffTime : 34ms
# 2024-06-19 11:13:58.302
# [iso : 160] [shutter : 1/6000.0] [fnum : 170] [ev : 0] [ct : 4824] [color_md : default] [focal_len : 240] [dzoom_ratio: 10000, delta:0],[latitude: 32.105905] [longitude: 35.206791] [rel_alt: 117.500 abs_alt: 802.541] </font>
# Parsing line: <font size="28">SrtCnt : 22395, DiffTime : 33ms
# 2024-06-19 11:13:58.336
# [iso : 160] [shutter : 1/6000.0] [fnum : 170] [ev : 0] [ct : 4824] [color_md : default] [focal_len : 240] [dzoom_ratio: 10000, delta:0],[latitude: 32.105912] [longitude: 35.206797] [rel_alt: 117.500 abs_alt: 802.541] </font>
# Parsing line: <font size="28">SrtCnt : 22396, DiffTime : 33ms
# 2024-06-19 11:13:58.369
# [iso : 160] [shutter : 1/6000.0] [fnum : 170] [ev : 0] [ct : 4823] [color_md : default] [focal_len : 240] [dzoom_ratio: 10000, delta:0],[latitude: 32.105912] [longitude: 35.206797] [rel_alt: 117.500 abs_alt: 802.541] </font>
# Parsing line: <font size="28">SrtCnt : 22397, DiffTime : 34ms
# 2024-06-19 11:13:58.403
# [iso : 160] [shutter : 1/6000.0] [fnum : 170] [ev : 0] [ct : 4823] [color_md : default] [focal_len : 240] [dzoom_ratio: 10000, delta:0],[latitude: 32.105912] [longitude: 35.206797] [rel_alt: 117.500 abs_alt: 802.541] </font>
# Parsing line: <font size="28">SrtCnt : 22398, DiffTime : 33ms
# 2024-06-19 11:13:58.436
# [iso : 160] [shutter : 1/6000.0] [fnum : 170] [ev : 0] [ct : 4822] [color_md : default] [focal_len : 240] [dzoom_ratio: 10000, delta:0],[latitude: 32.105920] [longitude: 35.206803] [rel_alt: 117.500 abs_alt: 802.541] </font>
# Parsing line: <font size="28">SrtCnt : 22399, DiffTime : 34ms
# 2024-06-19 11:13:58.470
# [iso : 160] [shutter : 1/6000.0] [fnum : 170] [ev : 0] [ct : 4822] [color_md : default] [focal_len : 240] [dzoom_ratio: 10000, delta:0],[latitude: 32.105920] [longitude: 35.206803] [rel_alt: 117.500 abs_alt: 802.541] </font>
# Parsing line: <font size="28">SrtCnt : 22400, DiffTime : 33ms
# 2024-06-19 11:13:58.503
# [iso : 160] [shutter : 1/6000.0] [fnum : 170] [ev : 0] [ct : 4820] [color_md : default] [focal_len : 240] [dzoom_ratio: 10000, delta:0],[latitude: 32.105920] [longitude: 35.206803] [rel_alt: 117.500 abs_alt: 802.541] </font>
# Parsing line: <font size="28">SrtCnt : 22401, DiffTime : 33ms
# 2024-06-19 11:13:58.536
# [iso : 160] [shutter : 1/6000.0] [fnum : 170] [ev : 0] [ct : 4820] [color_md : default] [focal_len : 240] [dzoom_ratio: 10000, delta:0],[latitude: 32.105927] [longitude: 35.206809] [rel_alt: 117.500 abs_alt: 802.541] </font>
# Parsing line: <font size="28">SrtCnt : 22402, DiffTime : 34ms
# 2024-06-19 11:13:58.569
# [iso : 160] [shutter : 1/6000.0] [fnum : 170] [ev : 0] [ct : 4819] [color_md : default] [focal_len : 240] [dzoom_ratio: 10000, delta:0],[latitude: 32.105927] [longitude: 35.206809] [rel_alt: 117.500 abs_alt: 802.541] </font>
# Parsing line: <font size="28">SrtCnt : 22403, DiffTime : 33ms
# 2024-06-19 11:13:58.603
# [iso : 160] [shutter : 1/6000.0] [fnum : 170] [ev : 0] [ct : 4819] [color_md : default] [focal_len : 240] [dzoom_ratio: 10000, delta:0],[latitude: 32.105927] [longitude: 35.206809] [rel_alt: 117.500 abs_alt: 802.541] </font>
# Parsing line: <font size="28">SrtCnt : 22404, DiffTime : 33ms
# 2024-06-19 11:13:58.636
# [iso : 160] [shutter : 1/6000.0] [fnum : 170] [ev : 0] [ct : 4817] [color_md : default] [focal_len : 240] [dzoom_ratio: 10000, delta:0],[latitude: 32.105935] [longitude: 35.206815] [rel_alt: 117.500 abs_alt: 802.541] </font>
# Parsing line: <font size="28">SrtCnt : 22405, DiffTime : 34ms
# 2024-06-19 11:13:58.669
# [iso : 160] [shutter : 1/6000.0] [fnum : 170] [ev : 0] [ct : 4817] [color_md : default] [focal_len : 240] [dzoom_ratio: 10000, delta:0],[latitude: 32.105935] [longitude: 35.206815] [rel_alt: 117.500 abs_alt: 802.541] </font>
# Parsing line: <font size="28">SrtCnt : 22406, DiffTime : 33ms
# 2024-06-19 11:13:58.703
# [iso : 160] [shutter : 1/6000.0] [fnum : 170] [ev : 0] [ct : 4815] [color_md : default] [focal_len : 240] [dzoom_ratio: 10000, delta:0],[latitude: 32.105935] [longitude: 35.206815] [rel_alt: 117.500 abs_alt: 802.541] </font>
# Parsing line: <font size="28">SrtCnt : 22407, DiffTime : 33ms
# 2024-06-19 11:13:58.736
# [iso : 160] [shutter : 1/6000.0] [fnum : 170] [ev : 0] [ct : 4815] [color_md : default] [focal_len : 240] [dzoom_ratio: 10000, delta:0],[latitude: 32.105942] [longitude: 35.206821] [rel_alt: 117.500 abs_alt: 802.541] </font>
# Parsing line: <font size="28">SrtCnt : 22408, DiffTime : 34ms
# 2024-06-19 11:13:58.770
# [iso : 160] [shutter : 1/6000.0] [fnum : 170] [ev : 0] [ct : 4813] [color_md : default] [focal_len : 240] [dzoom_ratio: 10000, delta:0],[latitude: 32.105942] [longitude: 35.206821] [rel_alt: 117.500 abs_alt: 802.541] </font>
# Parsing line: <font size="28">SrtCnt : 22409, DiffTime : 33ms
# 2024-06-19 11:13:58.803
# [iso : 160] [shutter : 1/6000.0] [fnum : 170] [ev : 0] [ct : 4813] [color_md : default] [focal_len : 240] [dzoom_ratio: 10000, delta:0],[latitude: 32.105942] [longitude: 35.206821] [rel_alt: 117.500 abs_alt: 802.541] </font>
# Parsing line: <font size="28">SrtCnt : 22410, DiffTime : 34ms
# 2024-06-19 11:13:58.836
# [iso : 160] [shutter : 1/6000.0] [fnum : 170] [ev : 0] [ct : 4813] [color_md : default] [focal_len : 240] [dzoom_ratio: 10000, delta:0],[latitude: 32.105949] [longitude: 35.206827] [rel_alt: 117.500 abs_alt: 802.541] </font>
# Parsing line: <font size="28">SrtCnt : 22411, DiffTime : 33ms
# 2024-06-19 11:13:58.870
# [iso : 160] [shutter : 1/6000.0] [fnum : 170] [ev : 0] [ct : 4811] [color_md : default] [focal_len : 240] [dzoom_ratio: 10000, delta:0],[latitude: 32.105949] [longitude: 35.206827] [rel_alt: 117.500 abs_alt: 802.541] </font>
# Parsing line: <font size="28">SrtCnt : 22412, DiffTime : 33ms
# 2024-06-19 11:13:58.903
# [iso : 160] [shutter : 1/6000.0] [fnum : 170] [ev : 0] [ct : 4811] [color_md : default] [focal_len : 240] [dzoom_ratio: 10000, delta:0],[latitude: 32.105949] [longitude: 35.206827] [rel_alt: 117.500 abs_alt: 802.541] </font>
# Parsing line: <font size="28">SrtCnt : 22413, DiffTime : 34ms
# 2024-06-19 11:13:58.936
# [iso : 160] [shutter : 1/6000.0] [fnum : 170] [ev : 0] [ct : 4809] [color_md : default] [focal_len : 240] [dzoom_ratio: 10000, delta:0],[latitude: 32.105957] [longitude: 35.206833] [rel_alt: 117.500 abs_alt: 802.541] </font>
# Parsing line: <font size="28">SrtCnt : 22414, DiffTime : 33ms
# 2024-06-19 11:13:58.970
# [iso : 160] [shutter : 1/6000.0] [fnum : 170] [ev : 0] [ct : 4809] [color_md : default] [focal_len : 240] [dzoom_ratio: 10000, delta:0],[latitude: 32.105957] [longitude: 35.206833] [rel_alt: 117.500 abs_alt: 802.541] </font>
# Parsing line: <font size="28">SrtCnt : 22415, DiffTime : 33ms
# 2024-06-19 11:13:59.003
# [iso : 160] [shutter : 1/6000.0] [fnum : 170] [ev : 0] [ct : 4807] [color_md : default] [focal_len : 240] [dzoom_ratio: 10000, delta:0],[latitude: 32.105957] [longitude: 35.206833] [rel_alt: 117.500 abs_alt: 802.541] </font>
# Parsing line: <font size="28">SrtCnt : 22416, DiffTime : 34ms
# 2024-06-19 11:13:59.037
# [iso : 160] [shutter : 1/6000.0] [fnum : 170] [ev : 0] [ct : 4807] [color_md : default] [focal_len : 240] [dzoom_ratio: 10000, delta:0],[latitude: 32.105964] [longitude: 35.206839] [rel_alt: 117.500 abs_alt: 802.541] </font>
# Parsing line: <font size="28">SrtCnt : 22417, DiffTime : 33ms
# 2024-06-19 11:13:59.070
# [iso : 160] [shutter : 1/6000.0] [fnum : 170] [ev : 0] [ct : 4806] [color_md : default] [focal_len : 240] [dzoom_ratio: 10000, delta:0],[latitude: 32.105964] [longitude: 35.206839] [rel_alt: 117.500 abs_alt: 802.541] </font>
# Parsing line: <font size="28">SrtCnt : 22418, DiffTime : 33ms
# 2024-06-19 11:13:59.103
# [iso : 160] [shutter : 1/6000.0] [fnum : 170] [ev : 0] [ct : 4806] [color_md : default] [focal_len : 240] [dzoom_ratio: 10000, delta:0],[latitude: 32.105964] [longitude: 35.206839] [rel_alt: 117.500 abs_alt: 802.541] </font>
# Parsing line: <font size="28">SrtCnt : 22419, DiffTime : 34ms
# 2024-06-19 11:13:59.136
# ...
# Parsing line: <font size="28">SrtCnt : 3387, DiffTime : 33ms
# 2024-06-19 11:37:01.977
# [iso : 110] [shutter : 1/5000.0] [fnum : 170] [ev : 0] [ct : 5145] [color_md : default] [focal_len : 240] [dzoom_ratio: 10000, delta:0],[latitude: 32.102581] [longitude: 35.209684] [rel_alt: 0.300 abs_alt: 685.553] </font>
# Parsing line: <font size="28">SrtCnt : 3388, DiffTime : 33ms
# 2024-06-19 11:37:02.011
# [iso : 110] [shutter : 1/5000.0] [fnum : 170] [ev : 0] [ct : 5145] [color_md : default] [focal_len : 240] [dzoom_ratio: 10000, delta:0],[latitude: 32.102581] [longitude: 35.209684] [rel_alt: 0.300 abs_alt: 685.553] </font>
# Parsing line: <font size="28">SrtCnt : 3389, DiffTime : 34ms
# 2024-06-19 11:37:02.044
# [iso : 110] [shutter : 1/5000.0] [fnum : 170] [ev : 0] [ct : 5145] [color_md : default] [focal_len : 240] [dzoom_ratio: 10000, delta:0],[latitude: 32.102581] [longitude: 35.209684] [rel_alt: 0.300 abs_alt: 685.553] </font>
# Parsing line: <font size="28">SrtCnt : 3390, DiffTime : 33ms
# 2024-06-19 11:37:02.078
# [iso : 110] [shutter : 1/5000.0] [fnum : 170] [ev : 0] [ct : 5147] [color_md : default] [focal_len : 240] [dzoom_ratio: 10000, delta:0],[latitude: 32.102581] [longitude: 35.209684] [rel_alt: 0.200 abs_alt: 685.453] </font>
# Parsing line: <font size="28">SrtCnt : 3391, DiffTime : 33ms
# 2024-06-19 11:37:02.111
# [iso : 110] [shutter : 1/5000.0] [fnum : 170] [ev : 0] [ct : 5147] [color_md : default] [focal_len : 240] [dzoom_ratio: 10000, delta:0],[latitude: 32.102581] [longitude: 35.209684] [rel_alt: 0.200 abs_alt: 685.453] </font>
# Parsing line: <font size="28">SrtCnt : 3392, DiffTime : 34ms
# 2024-06-19 11:37:02.144
# [iso : 110] [shutter : 1/5000.0] [fnum : 170] [ev : 0] [ct : 5150] [color_md : default] [focal_len : 240] [dzoom_ratio: 10000, delta:0],[latitude: 32.102581] [longitude: 35.209684] [rel_alt: 0.200 abs_alt: 685.453] </font>
# Parsing line: <font size="28">SrtCnt : 3393, DiffTime : 33ms
# 2024-06-19 11:37:02.178
# [iso : 110] [shutter : 1/5000.0] [fnum : 170] [ev : 0] [ct : 5150] [color_md : default] [focal_len : 240] [dzoom_ratio: 10000, delta:0],[latitude: 32.102581] [longitude: 35.209684] [rel_alt: 0.200 abs_alt: 685.453] </font>
# Parsing line: <font size="28">SrtCnt : 3394, DiffTime : 33ms
# 2024-06-19 11:37:02.211
# [iso : 110] [shutter : 1/5000.0] [fnum : 170] [ev : 0] [ct : 5152] [color_md : default] [focal_len : 240] [dzoom_ratio: 10000, delta:0],[latitude: 32.102581] [longitude: 35.209684] [rel_alt: 0.200 abs_alt: 685.453] </font>
# Parsing line: <font size="28">SrtCnt : 3395, DiffTime : 34ms
# 2024-06-19 11:37:02.244
# [iso : 110] [shutter : 1/5000.0] [fnum : 170] [ev : 0] [ct : 5152] [color_md : default] [focal_len : 240] [dzoom_ratio: 10000, delta:0],[latitude: 32.102581] [longitude: 35.209684] [rel_alt: 0.200 abs_alt: 685.453] </font>
# Parsing line: <font size="28">SrtCnt : 3396, DiffTime : 33ms
# 2024-06-19 11:37:02.279
# [iso : 110] [shutter : 1/5000.0] [fnum : 170] [ev : 0] [ct : 5154] [color_md : default] [focal_len : 240] [dzoom_ratio: 10000, delta:0],[latitude: 32.102581] [longitude: 35.209684] [rel_alt: 0.100 abs_alt: 685.353] </font>
# Parsing line: <font size="28">SrtCnt : 3397, DiffTime : 34ms
# 2024-06-19 11:37:02.311
# [iso : 110] [shutter : 1/5000.0] [fnum : 170] [ev : 0] [ct : 5154] [color_md : default] [focal_len : 240] [dzoom_ratio: 10000, delta:0],[latitude: 32.102581] [longitude: 35.209684] [rel_alt: 0.100 abs_alt: 685.353] </font>
# Parsing line: <font size="28">SrtCnt : 3398, DiffTime : 33ms
# 2024-06-19 11:37:02.344
# [iso : 110] [shutter : 1/5000.0] [fnum : 170] [ev : 0] [ct : 5156] [color_md : default] [focal_len : 240] [dzoom_ratio: 10000, delta:0],[latitude: 32.102581] [longitude: 35.209684] [rel_alt: 0.100 abs_alt: 685.353] </font>
# Parsing line: <font size="28">SrtCnt : 3399, DiffTime : 33ms
# 2024-06-19 11:37:02.378
# [iso : 110] [shutter : 1/5000.0] [fnum : 170] [ev : 0] [ct : 5156] [color_md : default] [focal_len : 240] [dzoom_ratio: 10000, delta:0],[latitude: 32.102581] [longitude: 35.209684] [rel_alt: 0.100 abs_alt: 685.353] </font>
# Parsing line: <font size="28">SrtCnt : 3400, DiffTime : 34ms
# 2024-06-19 11:37:02.411
# [iso : 110] [shutter : 1/5000.0] [fnum : 170] [ev : 0] [ct : 5158] [color_md : default] [focal_len : 240] [dzoom_ratio: 10000, delta:0],[latitude: 32.102581] [longitude: 35.209684] [rel_alt: 0.100 abs_alt: 685.353] </font>
# Parsing line: <font size="28">SrtCnt : 3401, DiffTime : 33ms
# 2024-06-19 11:37:02.444
# [iso : 110] [shutter : 1/5000.0] [fnum : 170] [ev : 0] [ct : 5158] [color_md : default] [focal_len : 240] [dzoom_ratio: 10000, delta:0],[latitude: 32.102581] [longitude: 35.209684] [rel_alt: 0.100 abs_alt: 685.353] </font>
# Parsing line: <font size="28">SrtCnt : 3402, DiffTime : 33ms
# 2024-06-19 11:37:02.478
# [iso : 110] [shutter : 1/5000.0] [fnum : 170] [ev : 0] [ct : 5159] [color_md : default] [focal_len : 240] [dzoom_ratio: 10000, delta:0],[latitude: 32.102581] [longitude: 35.209684] [rel_alt: 0.100 abs_alt: 685.353] </font>
# Parsing line: <font size="28">SrtCnt : 3403, DiffTime : 34ms
# 2024-06-19 11:37:02.511
# [iso : 110] [shutter : 1/5000.0] [fnum : 170] [ev : 0] [ct : 5159] [color_md : default] [focal_len : 240] [dzoom_ratio: 10000, delta:0],[latitude: 32.102581] [longitude: 35.209684] [rel_alt: 0.100 abs_alt: 685.353] </font>
# Parsing line: <font size="28">SrtCnt : 3404, DiffTime : 33ms
# 2024-06-19 11:37:02.544
# [iso : 110] [shutter : 1/5000.0] [fnum : 170] [ev : 0] [ct : 5161] [color_md : default] [focal_len : 240] [dzoom_ratio: 10000, delta:0],[latitude: 32.102581] [longitude: 35.209684] [rel_alt: 0.100 abs_alt: 685.353] </font>
# Parsing line: <font size="28">SrtCnt : 3405, DiffTime : 33ms
# 2024-06-19 11:37:02.579
# [iso : 110] [shutter : 1/5000.0] [fnum : 170] [ev : 0] [ct : 5161] [color_md : default] [focal_len : 240] [dzoom_ratio: 10000, delta:0],[latitude: 32.102581] [longitude: 35.209684] [rel_alt: 0.000 abs_alt: 685.253] </font>
# Parsing line: <font size="28">SrtCnt : 3406, DiffTime : 34ms
# 2024-06-19 11:37:02.611
# [iso : 110] [shutter : 1/5000.0] [fnum : 170] [ev : 0] [ct : 5162] [color_md : default] [focal_len : 240] [dzoom_ratio: 10000, delta:0],[latitude: 32.102581] [longitude: 35.209684] [rel_alt: 0.000 abs_alt: 685.253] </font>
# Parsing line: <font size="28">SrtCnt : 3407, DiffTime : 33ms
# 2024-06-19 11:37:02.645
# [iso : 110] [shutter : 1/5000.0] [fnum : 170] [ev : 0] [ct : 5162] [color_md : default] [focal_len : 240] [dzoom_ratio: 10000, delta:0],[latitude: 32.102581] [longitude: 35.209684] [rel_alt: 0.000 abs_alt: 685.253] </font>
# Parsing line: <font size="28">SrtCnt : 3408, DiffTime : 34ms
# 2024-06-19 11:37:02.679
# [iso : 110] [shutter : 1/5000.0] [fnum : 170] [ev : 0] [ct : 5164] [color_md : default] [focal_len : 240] [dzoom_ratio: 10000, delta:0],[latitude: 32.102581] [longitude: 35.209684] [rel_alt: 0.000 abs_alt: 685.253] </font>
# Parsing line: <font size="28">SrtCnt : 3409, DiffTime : 33ms
# 2024-06-19 11:37:02.712
# [iso : 110] [shutter : 1/5000.0] [fnum : 170] [ev : 0] [ct : 5164] [color_md : default] [focal_len : 240] [dzoom_ratio: 10000, delta:0],[latitude: 32.102581] [longitude: 35.209684] [rel_alt: 0.000 abs_alt: 685.253] </font>
# Parsing line: <font size="28">SrtCnt : 3410, DiffTime : 33ms
# 2024-06-19 11:37:02.745
# [iso : 110] [shutter : 1/5000.0] [fnum : 170] [ev : 0] [ct : 5165] [color_md : default] [focal_len : 240] [dzoom_ratio: 10000, delta:0],[latitude: 32.102581] [longitude: 35.209684] [rel_alt: 0.000 abs_alt: 685.253] </font>
# Parsing line: <font size="28">SrtCnt : 3411, DiffTime : 34ms
# 2024-06-19 11:37:02.778
# [iso : 110] [shutter : 1/5000.0] [fnum : 170] [ev : 0] [ct : 5165] [color_md : default] [focal_len : 240] [dzoom_ratio: 10000, delta:0],[latitude: 32.102581] [longitude: 35.209684] [rel_alt: 0.000 abs_alt: 685.253] </font>
# Parsing line: <font size="28">SrtCnt : 3412, DiffTime : 33ms
# 2024-06-19 11:37:02.811
# [iso : 110] [shutter : 1/5000.0] [fnum : 170] [ev : 0] [ct : 5167] [color_md : default] [focal_len : 240] [dzoom_ratio: 10000, delta:0],[latitude: 32.102581] [longitude: 35.209684] [rel_alt: 0.000 abs_alt: 685.253] </font>
# Parsing line: <font size="28">SrtCnt : 3413, DiffTime : 33ms
# 2024-06-19 11:37:02.845
# [iso : 110] [shutter : 1/5000.0] [fnum : 170] [ev : 0] [ct : 5167] [color_md : default] [focal_len : 240] [dzoom_ratio: 10000, delta:0],[latitude: 32.102581] [longitude: 35.209684] [rel_alt: 0.000 abs_alt: 685.253] </font>
# Parsing line: <font size="28">SrtCnt : 3414, DiffTime : 34ms
# 2024-06-19 11:37:02.879
# [iso : 110] [shutter : 1/5000.0] [fnum : 170] [ev : 0] [ct : 5168] [color_md : default] [focal_len : 240] [dzoom_ratio: 10000, delta:0],[latitude: 32.102581] [longitude: 35.209684] [rel_alt: 0.000 abs_alt: 685.253] </font>
# Parsing line: <font size="28">SrtCnt : 3415, DiffTime : 33ms
# 2024-06-19 11:37:02.912
# [iso : 110] [shutter : 1/5000.0] [fnum : 170] [ev : 0] [ct : 5168] [color_md : default] [focal_len : 240] [dzoom_ratio: 10000, delta:0],[latitude: 32.102581] [longitude: 35.209684] [rel_alt: 0.000 abs_alt: 685.253] </font>
# Parsing line: <font size="28">SrtCnt : 3416, DiffTime : 33ms
# 2024-06-19 11:37:02.948
# [iso : 110] [shutter : 1/5000.0] [fnum : 170] [ev : 0] [ct : 5169] [color_md : default] [focal_len : 240] [dzoom_ratio: 10000, delta:0],[latitude: 32.102581] [longitude: 35.209684] [rel_alt: 0.000 abs_alt: 685.253] </font>
# Parsing line: <font size="28">SrtCnt : 3417, DiffTime : 34ms
# 2024-06-19 11:37:02.979
# [iso : 110] [shutter : 1/5000.0] [fnum : 170] [ev : 0] [ct : 5169] [color_md : default] [focal_len : 240] [dzoom_ratio: 10000, delta:0],[latitude: 32.102581] [longitude: 35.209684] [rel_alt: 0.000 abs_alt: 685.253] </font>
# Parsing line: <font size="28">SrtCnt : 3418, DiffTime : 33ms
# 2024-06-19 11:37:03.012
# [iso : 110] [shutter : 1/5000.0] [fnum : 170] [ev : 0] [ct : 5171] [color_md : default] [focal_len : 240] [dzoom_ratio: 10000, delta:0],[latitude: 32.102581] [longitude: 35.209684] [rel_alt: 0.000 abs_alt: 685.253] </font>
# Parsing line: <font size="28">SrtCnt : 3419, DiffTime : 34ms
# 2024-06-19 11:37:03.045
# [iso : 110] [shutter : 1/5000.0] [fnum : 170] [ev : 0] [ct : 5171] [color_md : default] [focal_len : 240] [dzoom_ratio: 10000, delta:0],[latitude: 32.102581] [longitude: 35.209684] [rel_alt: 0.000 abs_alt: 685.253] </font>
# Parsing line: <font size="28">SrtCnt : 3420, DiffTime : 33ms
# 2024-06-19 11:37:03.079
# [iso : 110] [shutter : 1/5000.0] [fnum : 170] [ev : 0] [ct : 5172] [color_md : default] [focal_len : 240] [dzoom_ratio: 10000, delta:0],[latitude: 32.102581] [longitude: 35.209684] [rel_alt: 0.000 abs_alt: 685.253] </font>
# Parsing line: <font size="28">SrtCnt : 3421, DiffTime : 33ms
# 2024-06-19 11:37:03.112
# [iso : 110] [shutter : 1/5000.0] [fnum : 170] [ev : 0] [ct : 5172] [color_md : default] [focal_len : 240] [dzoom_ratio: 10000, delta:0],[latitude: 32.102581] [longitude: 35.209684] [rel_alt: 0.000 abs_alt: 685.253] </font>
# Parsing line: <font size="28">SrtCnt : 3422, DiffTime : 34ms
# 2024-06-19 11:37:03.145
# [iso : 110] [shutter : 1/5000.0] [fnum : 170] [ev : 0] [ct : 5173] [color_md : default] [focal_len : 240] [dzoom_ratio: 10000, delta:0],[latitude: 32.102581] [longitude: 35.209684] [rel_alt: 0.000 abs_alt: 685.253] </font>
# Parsing line: <font size="28">SrtCnt : 3423, DiffTime : 33ms
# 2024-06-19 11:37:03.178
# [iso : 110] [shutter : 1/5000.0] [fnum : 170] [ev : 0] [ct : 5173] [color_md : default] [focal_len : 240] [dzoom_ratio: 10000, delta:0],[latitude: 32.102580] [longitude: 35.209684] [rel_alt: 0.000 abs_alt: 685.253] </font>
# Parsing line: <font size="28">SrtCnt : 3424, DiffTime : 33ms
# 2024-06-19 11:37:03.212
# [iso : 110] [shutter : 1/5000.0] [fnum : 170] [ev : 0] [ct : 5174] [color_md : default] [focal_len : 240] [dzoom_ratio: 10000, delta:0],[latitude: 32.102580] [longitude: 35.209684] [rel_alt: 0.000 abs_alt: 685.253] </font>
# Parsing line: <font size="28">SrtCnt : 3425, DiffTime : 34ms
# 2024-06-19 11:37:03.245
# [iso : 110] [shutter : 1/5000.0] [fnum : 170] [ev : 0] [ct : 5174] [color_md : default] [focal_len : 240] [dzoom_ratio: 10000, delta:0],[latitude: 32.102580] [longitude: 35.209684] [rel_alt: 0.000 abs_alt: 685.253] </font>
# Parsing line: <font size="28">SrtCnt : 3426, DiffTime : 33ms
# 2024-06-19 11:37:03.279
# [iso : 110] [shutter : 1/5000.0] [fnum : 170] [ev : 0] [ct : 5175] [color_md : default] [focal_len : 240] [dzoom_ratio: 10000, delta:0],[latitude: 32.102580] [longitude: 35.209684] [rel_alt: 0.000 abs_alt: 685.253] </font>
# Parsing line: <font size="28">SrtCnt : 3427, DiffTime : 33ms
# 2024-06-19 11:37:03.312
# [iso : 110] [shutter : 1/5000.0] [fnum : 170] [ev : 0] [ct : 5175] [color_md : default] [focal_len : 240] [dzoom_ratio: 10000, delta:0],[latitude: 32.102580] [longitude: 35.209684] [rel_alt: 0.000 abs_alt: 685.253] </font>
# Parsing line: <font size="28">SrtCnt : 3428, DiffTime : 34ms
# 2024-06-19 11:37:03.345
# [iso : 110] [shutter : 1/5000.0] [fnum : 170] [ev : 0] [ct : 5176] [color_md : default] [focal_len : 240] [dzoom_ratio: 10000, delta:0],[latitude: 32.102580] [longitude: 35.209684] [rel_alt: 0.000 abs_alt: 685.253] </font>
# Parsing line: <font size="28">SrtCnt : 3429, DiffTime : 33ms
# 2024-06-19 11:37:03.379
# [iso : 110] [shutter : 1/5000.0] [fnum : 170] [ev : 0] [ct : 5176] [color_md : default] [focal_len : 240] [dzoom_ratio: 10000, delta:0],[latitude: 32.102580] [longitude: 35.209684] [rel_alt: 0.000 abs_alt: 685.253] </font>
# Parsing line: <font size="28">SrtCnt : 3430, DiffTime : 34ms
# 2024-06-19 11:37:03.412
# [iso : 110] [shutter : 1/5000.0] [fnum : 170] [ev : 0] [ct : 5176] [color_md : default] [focal_len : 240] [dzoom_ratio: 10000, delta:0],[latitude: 32.102580] [longitude: 35.209684] [rel_alt: 0.000 abs_alt: 685.253] </font>
# Parsing line: <font size="28">SrtCnt : 3431, DiffTime : 33ms
# 2024-06-19 11:37:03.445
# [iso : 110] [shutter : 1/5000.0] [fnum : 170] [ev : 0] [ct : 5176] [color_md : default] [focal_len : 240] [dzoom_ratio: 10000, delta:0],[latitude: 32.102580] [longitude: 35.209684] [rel_alt: 0.000 abs_alt: 685.253] </font>
# No GPS data found in /content/drive/MyDrive/PhotoGrammetry/logs/DJI_0009.SRT. Check format or regex pattern.
# [youtube] Extracting URL: https://www.youtube.com/watch?v=4djIhBzJtvk
# [youtube] 4djIhBzJtvk: Downloading webpage
# [youtube] 4djIhBzJtvk: Downloading ios player API JSON
# [youtube] 4djIhBzJtvk: Downloading mweb player API JSON
# [youtube] 4djIhBzJtvk: Downloading m3u8 information
# [info] 4djIhBzJtvk: Downloading 1 format(s): 137+140
# [download] Destination: /content/drive/MyDrive/PhotoGrammetry/videos/video_0010.f137.mp4
# [download] 100% of  446.28MiB in 00:00:16 at 26.74MiB/s
# [download] Destination: /content/drive/MyDrive/PhotoGrammetry/videos/video_0010.f140.m4a
# [download] 100% of   12.83MiB in 00:00:01 at 12.40MiB/s
# [Merger] Merging formats into "/content/drive/MyDrive/PhotoGrammetry/videos/video_0010.mp4"
# Deleting original file /content/drive/MyDrive/PhotoGrammetry/videos/video_0010.f137.mp4 (pass -k to keep)
# Deleting original file /content/drive/MyDrive/PhotoGrammetry/videos/video_0010.f140.m4a (pass -k to keep)
# [youtube] Extracting URL: https://www.youtube.com/watch?v=ftd4qKVyo6Q
# [youtube] ftd4qKVyo6Q: Downloading webpage
# [youtube] ftd4qKVyo6Q: Downloading ios player API JSON
# [youtube] ftd4qKVyo6Q: Downloading mweb player API JSON
# [youtube] ftd4qKVyo6Q: Downloading m3u8 information
# [info] ftd4qKVyo6Q: Downloading 1 format(s): 137+140
# [download] Destination: /content/drive/MyDrive/PhotoGrammetry/videos/video_0011.f137.mp4
# [download] 100% of  192.73MiB in 00:00:04 at 40.34MiB/s
# [download] Destination: /content/drive/MyDrive/PhotoGrammetry/videos/video_0011.f140.m4a
# [download] 100% of    5.56MiB in 00:00:00 at 17.58MiB/s
# [Merger] Merging formats into "/content/drive/MyDrive/PhotoGrammetry/videos/video_0011.mp4"
# Deleting original file /content/drive/MyDrive/PhotoGrammetry/videos/video_0011.f140.m4a (pass -k to keep)
# Deleting original file /content/drive/MyDrive/PhotoGrammetry/videos/video_0011.f137.mp4 (pass -k to keep)
